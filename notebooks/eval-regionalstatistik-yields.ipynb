# %% [markdown]
# # 2.2 Regionalstatistik Kreise-Level Crop Yields
#
# **Goal:** Fetch NUTS-3 (Landkreis) level crop yields from the Destatis Genesis / Regionalstatistik REST API and evaluate coverage for Brandenburg + Saxony (Lusatia focus area).
#
# - **Data source:** Regionalstatistik.de - same Genesis REST API as destatis.de but with Kreise-level data
# - **Table:** `41241-0002` - Erntemengen & Erträge nach Fruchtarten (Kreisergebnisse)
# - **Auth:** POST-only, token-as-username, password empty, form-encoded body (GET disabled since July 2025)
# - **Licence:** Datenlizenz Deutschland - Namensnennung - Version 2.0
#
# **Decision criteria:** If we get ≥10 years of yield data for ≥80% of BB/SN Landkreise => **ingest**.

# %%
from pathlib import Path
import io
import os
import duckdb
import pandas as pd
import matplotlib.pyplot as plt
import requests
from dotenv import load_dotenv
import json

# Load .env from project root
load_dotenv(Path("../.env"))

CACHE_DIR = Path("_cache")
DB_PATH = CACHE_DIR / "agri_weather_yield.duckdb"

# %% [markdown]
# API endpoints

# %%
GENESIS_BASE = "https://www-genesis.destatis.de/genesisWS/rest/2020"
REGIO_BASE = "https://www.regionalstatistik.de/genesisws/rest/2020"
POST_HEADERS = {"Content-Type": "application/x-www-form-urlencoded"}

# %% [markdown]
# Genesis auth (destatis.de) — token-as-username

# %%
GENESIS_TOKEN = os.environ.get("DESTATIS_API_TOKEN", "")
assert GENESIS_TOKEN, "Set DESTATIS_API_TOKEN in .env"
GENESIS_AUTH = {"username": GENESIS_TOKEN, "password": ""}

# %% [markdown]
# Regionalstatistik auth (separate registration)

# %%
REGIO_USER = os.environ.get("REGIONALSTATISTIK_GENESIS_USERNAME", "")
REGIO_PASS = os.environ.get("REGIONALSTATISTIK_GENESIS_PASSWORD", "")
assert REGIO_USER, "Set REGIONALSTATISTIK_GENESIS_USERNAME in .env"
REGIO_AUTH = {"username": REGIO_USER, "password": REGIO_PASS}

# %% [markdown]
# DuckDB connection (reuse existing mini DWH)

# %%
con = duckdb.connect(str(DB_PATH))
con.execute("install spatial; load spatial;")

# %%
print(f"""
Genesis token:  {GENESIS_TOKEN[:4]:*<16}
Regio user:     {REGIO_USER[:3]:*<8}
DuckDB path:    {DB_PATH}
""")
# Out:
# Genesis token:  ba3c************
# Regio user:     RE0*****
# DuckDB path:    _cache/agri_weather_yield.duckdb

# %% [markdown]
# ## 1. Login check
#
# Test connectivity against both Genesis (destatis.de) and Regionalstatistik APIs.

# %%
for name, base_url, auth in [
    ("Genesis", GENESIS_BASE, GENESIS_AUTH),
    ("Regionalstatistik", REGIO_BASE, REGIO_AUTH),
]:
    resp = requests.post(
        f"{base_url}/helloworld/logincheck",
        headers=POST_HEADERS,
        data={**auth, "language": "en"},
        timeout=15,
    )
    resp.raise_for_status()
    msg = resp.json().get("Status", resp.text[:200])
    ok = "successfully" in msg.lower()
    print(f"{'OK' if ok else 'ERROR'} {name}: {msg[:200]}")
    assert ok, f"{base_url} failed"
# Out:
# OK Genesis: You have been logged in and out successfully! If there were more than 3 parallel requests, those that had been running for more than 15 minutes were terminated
# OK Regionalstatistik: You have been logged in and out successfully! If there were more than 10 parallel requests, those that had been running for more than 15 minutes were terminated

# %% [markdown]
# So we may also conclude that:
#
# 1. Federal-level Genesis has a quota of 3 parallel requests with a 15 minute window.
# 2. Regional-level Genesis has a quota of 10 parallel requests with a 15 minute window.

# %% [markdown]
# Let's now identify the data set codes we're interested in. By inspection of the website, we know that we need to look closer at subject "41" (Bodennutzung und pflanzliche Erzeugung):

# %%
GENESIS_HEADERS = {**POST_HEADERS, "username": GENESIS_TOKEN, "password": ""}

resp = requests.post(
    f"{GENESIS_BASE}/catalogue/statistics",
    headers=GENESIS_HEADERS,
    data={
        "language": "de",
        "searchcriterion": "Code",
        "selection": "41*",
        "pagelength": "200",
    },
    timeout=30,
)
resp.raise_for_status()
result = resp.json()

# %%
# For legibility, we'll just craete data frames from JSON response payloads (simple one-liners
# instead of printing out arrays of objects). Performance ok for this purpose.
stats_df = pd.read_json(io.StringIO(json.dumps(result["List"])))  # assuming List properety exists in response
stats_df
# Out:
#      Code                                            Content  Cubes  \
# 0   41122  Repräsentative Agrarstrukturerhebung (ASE b. 2...     40
# 1   41141              Landwirtschaftszählung: Haupterhebung    176
# 2   41145                  Landwirtschaftszählung: Gartenbau     22
# 3   41161                 Strukturerhebung der Forstbetriebe      9
# 4   41213                    Allgemeine Zierpflanzenerhebung     25
# 5   41214                          Erhebung über Speisepilze      2
# 6   41215                                     Gemüseerhebung     16
# 7   41221                                  Baumschulerhebung      8
# 8   41231                              Baumobstanbauerhebung     12
# 9   41232                        Erhebung über Strauchbeeren     14
# 10  41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland     10
# 11  41243               Ernte- und Betriebsbericht: Baumobst      6
# 12  41244     Ernte- und Betriebsbericht: Reben und Weinmost     18
# 13  41252               Rebflächenerhebung (Weinbaukataster)      9
# 14  41253                             Erhebung der Weinernte     18
# 15  41254                         Erhebung der Weinerzeugung     24
# 16  41255                          Erhebung der Weinbestände     56
# 17  41261  Holzeinschlagsstatistik (forstl. Erzeugerbetri...     40
# 18  41271                         Bodennutzungshaupterhebung     29
# 19  41311   Allg. und Repräs. Erhebung über die Viehbestände      6
# 20  41312                        Viehbestandserhebung Rinder     18
# 21  41313                      Viehbestandserhebung Schweine     12
# 22  41314                        Viehbestandserhebung Schafe      6
# 23  41321          Geflügelstatistik: Erhebung in Brütereien     10
# 24  41322  Geflügelstatistik: Erh. in Geflügelschlachtereien     16
# 25  41323   Geflügelstatistik: Untern. mit Legehennenhaltung     14
# 26  41331        Schlachtungs- und Schlachtgewichtsstatistik      4
# 27  41362  Erhebung über die Erzeugung in Aquakulturbetri...     10
# 28  41363               Preiserhebung in Aquakulturbetrieben      1
#
#    Information
# 0         true
# 1         true
# 2         true
# 3         true
# 4         true
# 5         true
# 6         true
# 7         true
# 8         true
# 9         true
# 10        true
# 11        true
# 12        true
# 13        true
# 14        true
# 15        true
# 16        true
# 17        true
# 18        true
# 19        true
# 20        true
# 21        true
# 22        true
# 23        true
# 24        true
# 25        true
# 26        true
# 27        true
# 28       false

# %% [markdown]
# Inspecting the code descriptions, we're interested in:
#
# - **41241** - Ernte-u.Betriebsbericht: Feldfrüchte und Grünland -> field crops, our goal here (crop yields) -> this is enough for a first EDA
# - 41221 - Baumschulerhebung -> this is interesting, we'll investigate it separately, there is a likely correlation between certain arboreal families and sandy soils
# - 41243 - tree fruits like appes and pears, likely low signal for sandy soils
# - 41141 - will need to look closer
#
# Unrelated:
#
# - 4121* - vegetables and mushrooms
# - 41244 and 4125* are about grapes and wineries -> not really relevant (mountanous areas)
# - 413* are about livestock (cattle, birds, fish)
#
# So now we can focus on this code: 41241, which serves as a prefix in the Genesis taxonomy.

# %% [markdown]
# ## 2. Discover/peek at yield tables
#
# Since our goal is to explore data on crop yields, we'll search the Regionalstatistik catalog for table `41241` (Erntemengen & Erträge) and similar agriculture tables available at Kreise level.

# %% [markdown]
# ### Regionalstatistik catalog: yield tables at Kreise level (NUTS-3)
#
# Note:
#
# - Regionalstatistik needs auth in HEADERS (not body), see their OpenAPI/Swagger spec.
# - `logincheck` works with request body, but all other endpoints require headers.

# %%
REGIO_HEADERS = {**POST_HEADERS, "username": REGIO_USER, "password": REGIO_PASS}

resp = requests.post(
    f"{REGIO_BASE}/catalogue/tables",
    headers=REGIO_HEADERS,
    data={"language": "de", "searchcriterion": "Code", "selection": "41241*", "pagelength": "50"},
    timeout=30,
)
resp.raise_for_status()  # If your password changes, you'll need to reload .env (just rerun the first code cell)
result = resp.json()
tables = result.get("List", [])

result
# Out:
# {'Ident': {'Service': 'catalogue', 'Method': 'tables'},
#  'Status': {'Code': 0, 'Content': 'erfolgreich', 'Type': 'Information'},
#  'Parameter': {'username': '********************',
#   'password': '********************',
#   'selection': '41241*',
#   'area': 'Öffentlich',
#   'searchcriterion': 'Code',
#   'sortcriterion': 'Code',
#   'pagelength': '50',
#   'language': 'de'},
#  'List': [{'Code': '41241-01-03-4',
#    'Content': 'Erträge ausgewählter landwirtschaftlicher Feldfrüchte -\nJahressumme - regionale Tiefe: Kreise und krfr. Städte',
#    'Time': '1999 - 2025'},
#   {'Code': '41241-01-03-4-B',
#    'Content': 'Erträge ausgewählter landwirtschaftlicher Feldfrüchte -\nJahressumme - regionale Ebenen',
#    'Time': '1999 - 2025'}],
#  'Copyright': '© Statistische Ämter des Bundes und der Länder, Deutschland, 2026.\nDieses Werk ist lizenziert unter der Datenlizenz Deutschland\n- Namensnennung - Version 2.0.'}

# %% [markdown]
# -> Regionalstatistik: just two tables matching `41241*` prefix:

# %%
pd.read_json(io.StringIO(json.dumps(result["List"])))
# Out:
#               Code                                            Content  \
# 0    41241-01-03-4  Erträge ausgewählter landwirtschaftlicher Feld...
# 1  41241-01-03-4-B  Erträge ausgewählter landwirtschaftlicher Feld...
#
#           Time
# 0  1999 - 2025
# 1  1999 - 2025

# %% [markdown]
# ### Federal Genesis catalog: yield tables at Bundesland level (NUTS-1)

# %%
GENESIS_HEADERS = {**POST_HEADERS, "username": GENESIS_TOKEN, "password": ""}

resp = requests.post(
    f"{GENESIS_BASE}/catalogue/tables",
    headers=GENESIS_HEADERS,
    data={"language": "de", "searchcriterion": "Code", "selection": "41241*", "pagelength": "50"},
    timeout=30,
)
resp.raise_for_status()
result = resp.json()
tables = result.get("List", [])
result
# Out:
# {'Ident': {'Service': 'catalogue', 'Method': 'tables'},
#  'Status': {'Code': 0, 'Content': 'erfolgreich', 'Type': 'Information'},
#  'Parameter': {'username': '********************',
#   'password': '********************',
#   'selection': '41241*',
#   'area': 'Öffentlich',
#   'searchcriterion': 'Code',
#   'sortcriterion': 'Code',
#   'pagelength': '50',
#   'language': 'de'},
#  'List': [{'Code': '41241-0001',
#    'Content': 'Anbaufläche (Feldfrüchte und Grünland): Deutschland, Jahre (bis 2009), Fruchtarten',
#    'Time': '1950 - 2009'},
#   {'Code': '41241-0002',
#    'Content': 'Erntemenge (Feldfrüchte und Grünland): Deutschland, Jahre (bis 2009), Fruchtarten',
#    'Time': '1950 - 2009'},
#   {'Code': '41241-0003',
#    'Content': 'Ertrag je Hektar (Feldfrüchte und Grünland): Deutschland,\nJahre (bis 2009), Fruchtarten',
#    'Time': '1950 - 2009'},
#   {'Code': '41241-0004',
#    'Content': 'Landwirtschaftlich genutzte Fläche (Feldfrüchte und\nGrünland): Deutschland, Jahre (bis 2009), Kulturarten',
#    'Time': '1950 - 2009'},
#   {'Code': '41241-0005',
#    'Content': 'Anbaufläche, Erntemenge, Ertrag je Hektar (Feldfrüchte und\nGrünland): Deutschland, Jahre, Fruchtarten',
#    'Time': '2010 - 2025'},
#   {'Code': '41241-0006',
#    'Content': 'Erntemenge von Raufutter: Deutschland, Jahre, Fruchtarten,\nVerwendungszweck',
#    'Time': '2010 - 2025'},
#   {'Code': '41241-0010',
#    'Content': 'Anbaufläche, Erntemenge, Ertrag je Hektar (Feldfrüchte und\nGrünland): Bundesländer, Jahre, Fruchtarten',
#    'Time': '2010 - 2025'},
#   {'Code': '41241-0011',
#    'Content': 'Erntemenge von Raufutter: Bundesländer, Jahre, Fruchtarten,\nVerwendungszweck',
#    'Time': '2010 - 2025'}],
#  'Copyright': '© Statistisches Bundesamt (Destatis), 2026'}

# %% [markdown]
# -> Federal Genesis: eight tables matching `41241*` prefix:

# %%
pd.read_json(io.StringIO(json.dumps(result["List"])))
# Out:
#          Code                                            Content         Time
# 0  41241-0001  Anbaufläche (Feldfrüchte und Grünland): Deutsc...  1950 - 2009
# 1  41241-0002  Erntemenge (Feldfrüchte und Grünland): Deutsch...  1950 - 2009
# 2  41241-0003  Ertrag je Hektar (Feldfrüchte und Grünland): D...  1950 - 2009
# 3  41241-0004  Landwirtschaftlich genutzte Fläche (Feldfrücht...  1950 - 2009
# 4  41241-0005  Anbaufläche, Erntemenge, Ertrag je Hektar (Fel...  2010 - 2025
# 5  41241-0006  Erntemenge von Raufutter: Deutschland, Jahre, ...  2010 - 2025
# 6  41241-0010  Anbaufläche, Erntemenge, Ertrag je Hektar (Fel...  2010 - 2025
# 7  41241-0011  Erntemenge von Raufutter: Bundesländer, Jahre,...  2010 - 2025

# %% [markdown]
# ## 3. Download and ingest Bundesland level yield data
#
# First we're tackling the federal level data -> NUTS-1 mapping. Fetch tables
#
# 1. `41241-0003` from Federal Genesis in flat CSV format. This contains yields in dt/ha for major crops at national level (-> NUTS-0), and
# 2. `41241-0010` from Federal Genesis in flat CSV format. This contains yields in dt/ha for major crops at Bundesland level (-> NUTS-1),

# %% [markdown]
# ### Download yields from federal Genesis (Bundesländer level)
#
# First, a downloader utility function

# %%
def handle_genesis_response(resp: requests.Response, cache_csv: Path) -> None:
    import zipfile

    ct = resp.headers.get("content-type", "")
    print(f"HTTP {resp.status_code} | Content-Type: {ct} | Size: {len(resp.content) / 1024:.0f} KB")

    # Handle different response formats
    if "zip" in ct.lower() or resp.content[:2] == b"PK":
        with zipfile.ZipFile(io.BytesIO(resp.content)) as zf:
            names = zf.namelist()
            print(f"  zipped: {names}")
            if csv_name := [n for n in names if n.endswith(".csv")]:
                csv_text = zf.read(csv_name[0]).decode("utf-8-sig")
                cache_csv.write_text(csv_text, encoding="utf-8")
                print(f"  Extracted & cached: {cache_csv} ({len(csv_text) / 1024:.0f} KB)")
            else:
                print("  No CSV found in zip")
    elif "json" in ct.lower():
        if (data := resp.json()) and (csv_content := data.get("Object", "")) and ";" in str(csv_content)[:200]:
            cache_csv.write_text(csv_content, encoding="utf-8")
            print(f"  Cached JSON→CSV: {cache_csv} ({len(csv_content) / 1024:.0f} KB)")
        else:
            print(f"  Status: {data.get('Status', data)}")
    elif ";" in resp.text[:500]:
        cache_csv.write_text(resp.text, encoding="utf-8")
        print(f"  Cached raw CSV: {cache_csv} ({len(resp.text) / 1024:.0f} KB)")
    else:
        print(f"  Unknown format. Preview: {resp.text[:200]}")

# %%
def download_genesis_tables(table_code: str) -> None:
    cache_csv = CACHE_DIR / f"genesis_{table_code}.csv"
    if cache_csv.exists():
        return

    resp = requests.post(
        f"{GENESIS_BASE}/data/tablefile",
        headers=GENESIS_HEADERS,
        data={
            "name": table_code,
            "area": "all",
            "compress": "false",
            "format": "ffcsv",  # flat CSV with Geruropean semicolon delimiter and comma as decimal sep
            "language": "de",
            "startyear": "1999",
            "endyear": "2025",
        },
        timeout=120,
    )
    resp.raise_for_status()
    handle_genesis_response(resp, cache_csv)

# %%
for table_code, _description in [
    ("41241-0003", "National yields (Deutschland)"),
    ("41241-0010", "Bundesländer yields"),
]:
    download_genesis_tables(table_code)

# %%
bl_03_df = pd.read_csv(CACHE_DIR / "genesis_41241-0003.csv", sep=";", decimal=",", dtype={"statistics_code": str})
bl_03_df.describe()
# Out:
#               time
# count   418.000000
# mean   2004.000000
# std       3.166067
# min    1999.000000
# 25%    2001.000000
# 50%    2004.000000
# 75%    2007.000000
# max    2009.000000

# %% [markdown]
# The national yields data set ranges from 1999 to 2009, which won't help us much.

# %%
bl_03_df.head(3)
# Out:
#   statistics_code                                   statistics_label  \
# 0           41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
# 1           41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
# 2           41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
#
#   time_code time_label  time 1_variable_code       1_variable_label  \
# 0      JAHR       Jahr  2000           DINSG  Deutschland insgesamt
# 1      JAHR       Jahr  2000           DINSG  Deutschland insgesamt
# 2      JAHR       Jahr  1999           DINSG  Deutschland insgesamt
#
#   1_variable_attribute_code 1_variable_attribute_label 2_variable_code  \
# 0                        DG                Deutschland          FRUA03
# 1                        DG                Deutschland          FRUA03
# 2                        DG                Deutschland          FRUA03
#
#   2_variable_label 2_variable_attribute_code     2_variable_attribute_label  \
# 0      Fruchtarten                FRUART0513             Körnersonnenblumen
# 1      Fruchtarten               FRUART01212                   Sommergerste
# 2      Fruchtarten                 FRUART012  Futter- und Industriegetreide
#
#   value value_unit value_variable_code value_variable_label
# 0  24,8      dt/ha              ERT001     Ertrag je Hektar
# 1  46,3      dt/ha              ERT001     Ertrag je Hektar
# 2  59,2      dt/ha              ERT001     Ertrag je Hektar

# %% [markdown]
# ### Parse the Bundesländer ffcsv (flat CSV)
#
# The ffcsv (flat CSV) format is semicolon-separated with German number formatting. Column names encode the table dimensions.

# %%
bl_10_df = pd.read_csv(
    CACHE_DIR / "genesis_41241-0010.csv",
    sep=";",
    decimal=",",
    dtype={"statistics_code": str, "1_variable_attribute_code": str},
)
bl_10_df.head(3)
# Out:
#   statistics_code                                   statistics_label  \
# 0           41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
# 1           41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
# 2           41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
#
#   time_code time_label  time 1_variable_code 1_variable_label  \
# 0      JAHR       Jahr  2013           DLAND     Bundesländer
# 1      JAHR       Jahr  2013           DLAND     Bundesländer
# 2      JAHR       Jahr  2013           DLAND     Bundesländer
#
#   1_variable_attribute_code 1_variable_attribute_label 2_variable_code  \
# 0                        11                     Berlin          FRUA04
# 1                        11                     Berlin          FRUA04
# 2                        11                     Berlin          FRUA04
#
#   2_variable_label 2_variable_attribute_code  \
# 0      Fruchtarten               FRUART05112
# 1      Fruchtarten               FRUART05112
# 2      Fruchtarten               FRUART05112
#
#              2_variable_attribute_label value value_unit value_variable_code  \
# 0  Sommerraps, Winter- und Sommerrübsen     -         ha              FLC016
# 1  Sommerraps, Winter- und Sommerrübsen     -      dt/ha              ERT001
# 2  Sommerraps, Winter- und Sommerrübsen     -          t              ERN001
#
#   value_variable_label
# 0          Anbaufläche
# 1     Ertrag je Hektar
# 2           Erntemenge

# %% [markdown]
# #### Identify structure
#
# Table 41241-0010 uses a denormalized/flat format where each row is one measurement (area, yield, or harvest) for one state × crop × year combination.
#
# Unique value types (value_variable_code):

# %%
bl_10_df.groupby(["value_variable_code", "value_variable_label", "value_unit"]).value_counts()
# Out:
# value_variable_code  value_variable_label  value_unit  statistics_code  statistics_label                                   time_code  time_label  time  1_variable_code  1_variable_label  1_variable_attribute_code  1_variable_attribute_label  2_variable_code  2_variable_label  2_variable_attribute_code  2_variable_attribute_label                        value
# ERN001               Erntemenge            t           41241            Ernte-u.Betriebsbericht: Feldfrüchte und Grünland  JAHR       Jahr        2013  DLAND            Bundesländer      11                         Berlin                      FRUA04           Fruchtarten       FRUART05112                Sommerraps, Winter- und Sommerrübsen              -          1
#                                                                                                                                                   2025  DLAND            Bundesländer      14                         Sachsen                     FRUA04           Fruchtarten       FRUART065                  Raufutter                                         1527900    1
#                                                                                                                                                   2019  DLAND            Bundesländer      07                         Rheinland-Pfalz             FRUA04           Fruchtarten       FRUART0511                 Raps und Rübsen                                   121700     1
#                                                                                                                                                   2025  DLAND            Bundesländer      03                         Niedersachsen               FRUA04           Fruchtarten       FRUART0111                 Weizen                                            3208500    1
#                                                                                                                                                                                            02                         Hamburg                     FRUA04           Fruchtarten       FRUART025                  Sojabohnen                                        /          1
#                                                                                                                                                                                                                                                                                                                                                                             ..
# FLC016               Anbaufläche           ha          41241            Ernte-u.Betriebsbericht: Feldfrüchte und Grünland  JAHR       Jahr        2018  DLAND            Bundesländer      01                         Schleswig-Holstein          FRUA04           Fruchtarten       FRUART0124                 Triticale                                         5900       1
#                                                                                                                                                   2024  DLAND            Bundesländer      02                         Hamburg                     FRUA04           Fruchtarten       FRUART065                  Raufutter                                         6900       1
#                                                                                                                                                   2016  DLAND            Bundesländer      03                         Niedersachsen               FRUA04           Fruchtarten       FRUART05111                Winterraps                                        121500     1
#                                                                                                                                                   2010  DLAND            Bundesländer      12                         Brandenburg                 FRUA04           Fruchtarten       FRUART01111DE              Winterweizen (einschließlich Dinkel und Einkorn)  156104     1
#                                                                                                                                                   2019  DLAND            Bundesländer      09                         Bayern                      FRUA04           Fruchtarten       FRUART0122                 Hafer                                             21000      1
# Name: count, Length: 23808, dtype: int64

# %%
bl_10_df.groupby(["value_variable_code", "value_variable_label", "value_unit"]).size().reset_index(name="n")
# Out:
#   value_variable_code value_variable_label value_unit     n
# 0              ERN001           Erntemenge          t  7936
# 1              ERT001     Ertrag je Hektar      dt/ha  7936
# 2              FLC016          Anbaufläche         ha  7936

# %% [markdown]
# Unique Bundesländer:

# %%
bl_10_df["1_variable_attribute_code"].nunique()
# Out:
# 16

# %% [markdown]
# Unique years:

# %%
print(sorted(bl_10_df["time"].unique()))
# Out:
# [np.int64(2010), np.int64(2011), np.int64(2012), np.int64(2013), np.int64(2014), np.int64(2015), np.int64(2016), np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023), np.int64(2024), np.int64(2025)]

# %% [markdown]
# Unique crops:

# %%
bl_10_df["2_variable_attribute_code"].nunique()
# Out:
# 31

# %% [markdown]
# Crop codes:

# %%
bl_10_df[["2_variable_attribute_code", "2_variable_attribute_label"]].drop_duplicates().sort_values(
    "2_variable_attribute_code"
)
# Out:
#     2_variable_attribute_code  \
# 9                  FRUART0111
# 459             FRUART01111DE
# 39              FRUART01112OH
# 54                FRUART01113
# 48                FRUART01121
# 90                 FRUART0121
# 27                FRUART01211
# 18                FRUART01212
# 21                 FRUART0122
# 99                 FRUART0123
# 57                 FRUART0124
# 63              FRUART013CCM1
# 30               FRUART01EKM1
# 180                 FRUART01G
# 138              FRUART01OKM1
# 267                 FRUART022
# 15                FRUART024OF
# 12                  FRUART025
# 24                 FRUART02LG
# 396                 FRUART031
# 42                  FRUART032
# 6                  FRUART0511
# 126               FRUART05111
# 0                 FRUART05112
# 252                FRUART0515
# 114                FRUART0631
# 111               FRUART064G1
# 3                   FRUART065
# 78                 FRUART067S
# 51                  FRUART081
# 108                 FRUART082
#
#                             2_variable_attribute_label
# 9                                               Weizen
# 459   Winterweizen (einschließlich Dinkel und Einkorn)
# 39                      Sommerweizen (ohne Hartweizen)
# 54                                  Hartweizen (Durum)
# 48                       Roggen und Wintermenggetreide
# 90                                              Gerste
# 27                                        Wintergerste
# 18                                        Sommergerste
# 21                                               Hafer
# 99                                  Sommermenggetreide
# 57                                           Triticale
# 63        Körnermais/Mais zum Ausreifen (einschl. CCM)
# 30   Getreide zur Körnergew. (einschl. Körnermais, ...
# 180                     Getreide zur Ganzpflanzenernte
# 138     Getreide zur Körnergew. (ohne Körnermais, CCM)
# 267                                        Ackerbohnen
# 15                          Erbsen (ohne Frischerbsen)
# 12                                          Sojabohnen
# 24       Leguminosen zur Ganzpflanzenernte (z.B. Klee)
# 396                                         Kartoffeln
# 42                                         Zuckerrüben
# 6                                      Raps und Rübsen
# 126                                         Winterraps
# 0                 Sommerraps, Winter- und Sommerrübsen
# 252                                       Sonnenblumen
# 114  Feldgras/Grasanbau auf dem Ackerland (inkl.Mis...
# 111      Silomais/Grünmais einschl. Lieschkolbenschrot
# 3                                            Raufutter
# 78                                          Süßlupinen
# 51                             Wiesen (Schnittnutzung)
# 108        Weiden (einschließlich Mähweiden und Almen)

# %% [markdown]
# #### Clean: extract yields (dt/ha) for key crops
#
# Filter to yield rows only (ERT001 = Ertrag je Hektar):

# %%
yields_df = bl_10_df[bl_10_df["value_variable_code"] == "ERT001"].copy()
yields_df
# Out:
#       statistics_code                                   statistics_label  \
# 1               41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
# 4               41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
# 7               41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
# 10              41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
# 13              41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
# ...               ...                                                ...
# 23794           41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
# 23797           41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
# 23800           41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
# 23803           41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
# 23806           41241  Ernte-u.Betriebsbericht: Feldfrüchte und Grünland
#
#       time_code time_label  time 1_variable_code 1_variable_label  \
# 1          JAHR       Jahr  2013           DLAND     Bundesländer
# 4          JAHR       Jahr  2025           DLAND     Bundesländer
# 7          JAHR       Jahr  2019           DLAND     Bundesländer
# 10         JAHR       Jahr  2025           DLAND     Bundesländer
# 13         JAHR       Jahr  2025           DLAND     Bundesländer
# ...         ...        ...   ...             ...              ...
# 23794      JAHR       Jahr  2018           DLAND     Bundesländer
# 23797      JAHR       Jahr  2024           DLAND     Bundesländer
# 23800      JAHR       Jahr  2016           DLAND     Bundesländer
# 23803      JAHR       Jahr  2010           DLAND     Bundesländer
# 23806      JAHR       Jahr  2019           DLAND     Bundesländer
#
#       1_variable_attribute_code 1_variable_attribute_label 2_variable_code  \
# 1                            11                     Berlin          FRUA04
# 4                            14                    Sachsen          FRUA04
# 7                            07            Rheinland-Pfalz          FRUA04
# 10                           03              Niedersachsen          FRUA04
# 13                           02                    Hamburg          FRUA04
# ...                         ...                        ...             ...
# 23794                        01         Schleswig-Holstein          FRUA04
# 23797                        02                    Hamburg          FRUA04
# 23800                        03              Niedersachsen          FRUA04
# 23803                        12                Brandenburg          FRUA04
# 23806                        09                     Bayern          FRUA04
#
#       2_variable_label 2_variable_attribute_code  \
# 1          Fruchtarten               FRUART05112
# 4          Fruchtarten                 FRUART065
# 7          Fruchtarten                FRUART0511
# 10         Fruchtarten                FRUART0111
# 13         Fruchtarten                 FRUART025
# ...                ...                       ...
# 23794      Fruchtarten                FRUART0124
# 23797      Fruchtarten                 FRUART065
# 23800      Fruchtarten               FRUART05111
# 23803      Fruchtarten             FRUART01111DE
# 23806      Fruchtarten                FRUART0122
#
#                              2_variable_attribute_label value value_unit  \
# 1                  Sommerraps, Winter- und Sommerrübsen     -      dt/ha
# 4                                             Raufutter  65,6      dt/ha
# 7                                       Raps und Rübsen  33,7      dt/ha
# 10                                               Weizen  83,0      dt/ha
# 13                                           Sojabohnen     /      dt/ha
# ...                                                 ...   ...        ...
# 23794                                         Triticale  57,5      dt/ha
# 23797                                         Raufutter     /      dt/ha
# 23800                                        Winterraps  36,8      dt/ha
# 23803  Winterweizen (einschließlich Dinkel und Einkorn)  62,7      dt/ha
# 23806                                             Hafer  38,7      dt/ha
#
#       value_variable_code value_variable_label
# 1                  ERT001     Ertrag je Hektar
# 4                  ERT001     Ertrag je Hektar
# 7                  ERT001     Ertrag je Hektar
# 10                 ERT001     Ertrag je Hektar
# 13                 ERT001     Ertrag je Hektar
# ...                   ...                  ...
# 23794              ERT001     Ertrag je Hektar
# 23797              ERT001     Ertrag je Hektar
# 23800              ERT001     Ertrag je Hektar
# 23803              ERT001     Ertrag je Hektar
# 23806              ERT001     Ertrag je Hektar
#
# [7936 rows x 17 columns]

# %%
# Rename columns for convenience:
yields_df = yields_df.rename(
    columns={
        "time": "year",
        "1_variable_attribute_code": "bundesland_code",
        "1_variable_attribute_label": "bundesland_name",
        "2_variable_attribute_code": "crop_code",
        "2_variable_attribute_label": "crop_name",
        "value": "yield_dt_ha_str",
    }
)

# %%
# Parse year and yield
yields_df["year"] = pd.to_numeric(yields_df["year"], errors="coerce").astype("Int64")
yields_df["yield_dt_ha_str"] = yields_df["yield_dt_ha_str"].str.strip().replace(["-", "...", ".", "/", "x", "–"], pd.NA)
yields_df["yield_dt_ha"] = pd.to_numeric(
    yields_df["yield_dt_ha_str"].str.replace(",", ".", regex=False), errors="coerce"
)
yields_df["yield_t_ha"] = yields_df["yield_dt_ha"] / 10.0

# %%
# Drop rows without valid data
yields_df = yields_df.dropna(subset=["yield_dt_ha", "year"])

# %%
# Keep relevant columns
df = yields_df[
    ["year", "bundesland_code", "bundesland_name", "crop_code", "crop_name", "yield_dt_ha", "yield_t_ha"]
].copy()

KEY_CROPS = {
    "FRUART01111DE": "Winterweizen",
    "FRUART01121": "Roggen",
    "FRUART01211": "Wintergerste",
    "FRUART01212": "Sommergerste",
    "FRUART031": "Kartoffeln",
    "FRUART032": "Zuckerrüben",
    "FRUART05111": "Winterraps",
    "FRUART064G1": "Silomais",
}

# %% [markdown]
# Total yield rows (all crops, all states) = 5870:

# %%
len(df)
# Out:
# 5870

# %% [markdown]
# Year range (from, to):

# %%
print(f"{df['year'].min()} - {df['year'].max()}")
# Out:
# 2010 - 2025

# %% [markdown]
# States (13 out of 16, remainder are the city states Berlin, Hamburg, Bremen):

# %%
df["bundesland_code"].nunique()
# Out:
# 13

# %% [markdown]
# Crops with data:

# %%
df["crop_code"].nunique()
# Out:
# 31

# %% [markdown]
# Key crop coverage (rows per crop):

# %%
for code, name in KEY_CROPS.items():
    n = len(df[df["crop_code"] == code])
    states = df[df["crop_code"] == code]["bundesland_code"].nunique()
    print(f"  {name:20s} ({code:16s}): {n:4d} rows, {states:2d} states{'!' if states < 13 else ''}")

df.head(5)
# Out:
#   Winterweizen         (FRUART01111DE   ):  208 rows, 13 states
#   Roggen               (FRUART01121     ):  208 rows, 13 states
#   Wintergerste         (FRUART01211     ):  208 rows, 13 states
#   Sommergerste         (FRUART01212     ):  208 rows, 13 states
#   Kartoffeln           (FRUART031       ):  208 rows, 13 states
#   Zuckerrüben          (FRUART032       ):  192 rows, 12 states!
#   Winterraps           (FRUART05111     ):  207 rows, 13 states
#   Silomais             (FRUART064G1     ):  208 rows, 13 states
#     year bundesland_code  bundesland_name    crop_code  \
# 4   2025              14          Sachsen    FRUART065
# 7   2019              07  Rheinland-Pfalz   FRUART0511
# 10  2025              03    Niedersachsen   FRUART0111
# 16  2013              07  Rheinland-Pfalz  FRUART024OF
# 19  2019              10         Saarland  FRUART01212
#
#                      crop_name  yield_dt_ha  yield_t_ha
# 4                    Raufutter         65.6        6.56
# 7              Raps und Rübsen         33.7        3.37
# 10                      Weizen         83.0        8.30
# 16  Erbsen (ohne Frischerbsen)         45.8        4.58
# 19                Sommergerste         43.6        4.36

# %% [markdown]
# We should make sure that the `bundesland_code` column is parseed verbatim with padded zeros, as a string. This is crucial for mapping.

# %% [markdown]
# ### Map Bundesland -> NUTS-1 and Ingest into DuckDB
#
# Genesis table 41241-0010 provides **Bundesländer-level** yields (NUTS-1). We map the 2-digit Destatis Bundesland codes to NUTS-1 IDs. Obviously, 16 Bundeslaender <=> 16 NUTS-1 regions in DE.

# %%
# DuckDB nuts1 table has NUTS_ID and NUTS_NAME for German states.
nuts1_df = con.execute("""
    select nuts_id, nuts_name from nuts1 where cntr_code = 'DE'
""").fetchdf()
nuts1_df
# Out:
#    NUTS_ID               NUTS_NAME
# 0      DE1       Baden-Württemberg
# 1      DE6                 Hamburg
# 2      DE7                  Hessen
# 3      DE8  Mecklenburg-Vorpommern
# 4      DE9           Niedersachsen
# 5      DEA     Nordrhein-Westfalen
# 6      DEB         Rheinland-Pfalz
# 7      DEC                Saarland
# 8      DED                 Sachsen
# 9      DEE          Sachsen-Anhalt
# 10     DEF      Schleswig-Holstein
# 11     DEG               Thüringen
# 12     DE2                  Bayern
# 13     DE3                  Berlin
# 14     DE4             Brandenburg
# 15     DE5                  Bremen

# %%
# Known mapping: Destatis 2-digit BL code → NUTS-1 (from BKG/Destatis documentation)
BL_TO_NUTS1 = {
    "01": "DEF",  # Schleswig-Holstein
    "02": "DE6",  # Hamburg
    "03": "DE9",  # Niedersachsen
    "04": "DE5",  # Bremen
    "05": "DEA",  # Nordrhein-Westfalen
    "06": "DE7",  # Hessen
    "07": "DEB",  # Rheinland-Pfalz
    "08": "DE1",  # Baden-Württemberg
    "09": "DE2",  # Bayern
    "10": "DEC",  # Saarland
    "11": "DE3",  # Berlin
    "12": "DE4",  # Brandenburg
    "13": "DE8",  # Mecklenburg-Vorpommern
    "14": "DED",  # Sachsen
    "15": "DEE",  # Sachsen-Anhalt
    "16": "DEG",  # Thüringen
}

# %% [markdown]
# Let's make sure that the mapping is correct.

# %%
df["nuts1_id"] = df["bundesland_code"].map(BL_TO_NUTS1)
mapped = df["nuts1_id"].notna().sum()
assert mapped == len(df), "Incomplete mapping!"
f"Mapped: {mapped}/{len(df)} rows ({mapped / len(df) * 100:.1f}%)"
# Out:
# 'Mapped: 5870/5870 rows (100.0%)'

# %% [markdown]
# We'll now verify the mapping. It's jsut the 13 rows to consider.

# %%
verify = df[["bundesland_code", "bundesland_name", "nuts1_id"]].drop_duplicates().sort_values("bundesland_code")
verify
# Out:
#     bundesland_code         bundesland_name nuts1_id
# 139              01      Schleswig-Holstein      DEF
# 10               03           Niedersachsen      DE9
# 64               05     Nordrhein-Westfalen      DEA
# 109              06                  Hessen      DE7
# 7                07         Rheinland-Pfalz      DEB
# 70               08       Baden-Württemberg      DE1
# 25               09                  Bayern      DE2
# 19               10                Saarland      DEC
# 49               12             Brandenburg      DE4
# 184              13  Mecklenburg-Vorpommern      DE8
# 4                14                 Sachsen      DED
# 115              15          Sachsen-Anhalt      DEE
# 37               16               Thüringen      DEG

# %%
# Verify by joining on NUTS_ID == nuts1_id
n_unmatched = 0
for _, r in verify.iterrows():
    nuts_name = nuts1_df[nuts1_df["NUTS_ID"] == r.nuts1_id]["NUTS_NAME"].values
    nuts_name = nuts_name[0] if len(nuts_name) > 0 else "NOT FOUND"  # in case no match
    match = (
        "OK: "
        if r.bundesland_name.lower() in nuts_name.lower() or nuts_name.lower() in r.bundesland_name.lower()
        else "?"
    )
    if match == "?":
        n_unmatched += 1
    print(f"  {match} BL {r.bundesland_code} ({r.bundesland_name:25s}) → {r.nuts1_id} ({nuts_name})")
assert n_unmatched == 0, "Not all Bundeslaender matched a NUTS-1 id"
# Out:
#   OK:  BL 01 (Schleswig-Holstein       ) → DEF (Schleswig-Holstein)
#   OK:  BL 03 (Niedersachsen            ) → DE9 (Niedersachsen)
#   OK:  BL 05 (Nordrhein-Westfalen      ) → DEA (Nordrhein-Westfalen)
#   OK:  BL 06 (Hessen                   ) → DE7 (Hessen)
#   OK:  BL 07 (Rheinland-Pfalz          ) → DEB (Rheinland-Pfalz)
#   OK:  BL 08 (Baden-Württemberg        ) → DE1 (Baden-Württemberg)
#   OK:  BL 09 (Bayern                   ) → DE2 (Bayern)
#   OK:  BL 10 (Saarland                 ) → DEC (Saarland)
#   OK:  BL 12 (Brandenburg              ) → DE4 (Brandenburg)
#   OK:  BL 13 (Mecklenburg-Vorpommern   ) → DE8 (Mecklenburg-Vorpommern)
#   OK:  BL 14 (Sachsen                  ) → DED (Sachsen)
#   OK:  BL 15 (Sachsen-Anhalt           ) → DEE (Sachsen-Anhalt)
#   OK:  BL 16 (Thüringen                ) → DEG (Thüringen)

# %%
# Same verification logic, expressed in pandas
verify_pd = (
    df[["bundesland_code", "bundesland_name", "nuts1_id"]]
    .drop_duplicates()
    .sort_values("bundesland_code")
    .merge(
        nuts1_df[["NUTS_ID", "NUTS_NAME"]].rename(columns={"NUTS_ID": "nuts1_id", "NUTS_NAME": "nuts1_name"}),
        on="nuts1_id",
        how="left",
    )
)

verify_pd["match"] = verify_pd.apply(
    lambda r: (
        "OK"
        if pd.notna(r["nuts1_name"])
        and (
            r["bundesland_name"].lower() in r["nuts1_name"].lower()
            or r["nuts1_name"].lower() in r["bundesland_name"].lower()
        )
        else "?"
    ),
    axis=1,
)

verify_pd
# Out:
#    bundesland_code         bundesland_name nuts1_id              nuts1_name  \
# 0               01      Schleswig-Holstein      DEF      Schleswig-Holstein
# 1               03           Niedersachsen      DE9           Niedersachsen
# 2               05     Nordrhein-Westfalen      DEA     Nordrhein-Westfalen
# 3               06                  Hessen      DE7                  Hessen
# 4               07         Rheinland-Pfalz      DEB         Rheinland-Pfalz
# 5               08       Baden-Württemberg      DE1       Baden-Württemberg
# 6               09                  Bayern      DE2                  Bayern
# 7               10                Saarland      DEC                Saarland
# 8               12             Brandenburg      DE4             Brandenburg
# 9               13  Mecklenburg-Vorpommern      DE8  Mecklenburg-Vorpommern
# 10              14                 Sachsen      DED                 Sachsen
# 11              15          Sachsen-Anhalt      DEE          Sachsen-Anhalt
# 12              16               Thüringen      DEG               Thüringen
#
#    match
# 0     OK
# 1     OK
# 2     OK
# 3     OK
# 4     OK
# 5     OK
# 6     OK
# 7     OK
# 8     OK
# 9     OK
# 10    OK
# 11    OK
# 12    OK

# %%
# Same verification logic, expressed in DuckDB SQL
con.register("verify_df", df[["bundesland_code", "bundesland_name", "nuts1_id"]].drop_duplicates())
con.register("nuts1_names", nuts1_df[["NUTS_ID", "NUTS_NAME"]])

verify_sql = con.execute("""
    select case when n.nuts_name is not null
                 and ( lower(v.bundesland_name) like '%' || lower(n.nuts_name) || '%'
                     or lower(n.nuts_name) like '%' || lower(v.bundesland_name) || '%')
                then 'OK'
                else '?'
           end as match
         , v.bundesland_code
         , v.bundesland_name
         , v.nuts1_id
         , coalesce(n.nuts_name, 'NOT FOUND') as nuts1_name
    from verify_df v
    left join nuts1_names n on n.NUTS_ID = v.nuts1_id
    order by v.bundesland_code
""").df()

verify_sql
# Out:
#    match bundesland_code         bundesland_name nuts1_id  \
# 0     OK              01      Schleswig-Holstein      DEF
# 1     OK              03           Niedersachsen      DE9
# 2     OK              05     Nordrhein-Westfalen      DEA
# 3     OK              06                  Hessen      DE7
# 4     OK              07         Rheinland-Pfalz      DEB
# 5     OK              08       Baden-Württemberg      DE1
# 6     OK              09                  Bayern      DE2
# 7     OK              10                Saarland      DEC
# 8     OK              12             Brandenburg      DE4
# 9     OK              13  Mecklenburg-Vorpommern      DE8
# 10    OK              14                 Sachsen      DED
# 11    OK              15          Sachsen-Anhalt      DEE
# 12    OK              16               Thüringen      DEG
#
#                 nuts1_name
# 0       Schleswig-Holstein
# 1            Niedersachsen
# 2      Nordrhein-Westfalen
# 3                   Hessen
# 4          Rheinland-Pfalz
# 5        Baden-Württemberg
# 6                   Bayern
# 7                 Saarland
# 8              Brandenburg
# 9   Mecklenburg-Vorpommern
# 10                 Sachsen
# 11          Sachsen-Anhalt
# 12               Thüringen

# %% [markdown]
# Now we can ingest it into our data store:

# %%
con.execute("drop table if exists yields_bundesland")
con.execute("""
    create table yields_bundesland as
    select * from df
""")
n = con.execute("select count(*) from yields_bundesland").fetchone()[0]
print(f"DuckDB table 'yields_bundesland': {n:,} rows")
# Out:
# DuckDB table 'yields_bundesland': 5,870 rows

# %% [markdown]
# We'll perform a quick vericiation using Winterweizen yields for BB and SN (2020-2024):

# %%
sample = con.execute("""
    select year, bundesland_name, crop_name,
           yield_dt_ha, yield_t_ha, nuts1_id
    from yields_bundesland
    where nuts1_id IN ('DE4', 'DED')
      and crop_code = 'FRUART01111DE'
      and year >= 2020
    order BY year, bundesland_name
""").fetchdf()
sample
# Out:
#     year bundesland_name                                         crop_name  \
# 0   2020     Brandenburg  Winterweizen (einschließlich Dinkel und Einkorn)
# 1   2020         Sachsen  Winterweizen (einschließlich Dinkel und Einkorn)
# 2   2021     Brandenburg  Winterweizen (einschließlich Dinkel und Einkorn)
# 3   2021         Sachsen  Winterweizen (einschließlich Dinkel und Einkorn)
# 4   2022     Brandenburg  Winterweizen (einschließlich Dinkel und Einkorn)
# 5   2022         Sachsen  Winterweizen (einschließlich Dinkel und Einkorn)
# 6   2023     Brandenburg  Winterweizen (einschließlich Dinkel und Einkorn)
# 7   2023         Sachsen  Winterweizen (einschließlich Dinkel und Einkorn)
# 8   2024     Brandenburg  Winterweizen (einschließlich Dinkel und Einkorn)
# 9   2024         Sachsen  Winterweizen (einschließlich Dinkel und Einkorn)
# 10  2025     Brandenburg  Winterweizen (einschließlich Dinkel und Einkorn)
# 11  2025         Sachsen  Winterweizen (einschließlich Dinkel und Einkorn)
#
#     yield_dt_ha  yield_t_ha nuts1_id
# 0          65.2        6.52      DE4
# 1          77.0        7.70      DED
# 2          58.9        5.89      DE4
# 3          74.9        7.49      DED
# 4          65.6        6.56      DE4
# 5          68.7        6.87      DED
# 6          62.9        6.29      DE4
# 7          78.3        7.83      DED
# 8          63.0        6.30      DE4
# 9          76.6        7.66      DED
# 10         63.2        6.32      DE4
# 11         79.4        7.94      DED

# %% [markdown]
# ## 4. Download and ingest Kreise-level yield data (Regionalstatistik)
#
# Fetch table `41241-0002` (Erntemengen & Erträge at Kreise level) from Regionalstatistik.de using the dedicated credentials.

# %%
import time as _time

KREISE_TABLE = "41241-01-03-4"
cache_kreise = CACHE_DIR / f"regio_{KREISE_TABLE}.csv"

if cache_kreise.exists():
    print(f"Table {KREISE_TABLE}: cached ({cache_kreise.stat().st_size / 1024:.0f} KB)")
else:
    # Check ALL jobs (broad wildcard)
    resp = requests.post(
        f"{REGIO_BASE}/catalogue/jobs",
        headers=REGIO_HEADERS,
        data={"language": "de", "selection": "*", "pagelength": "50", "type": "Alle"},
        timeout=30,
    )
    resp.raise_for_status()
    result = resp.json()
    jobs = result.get("List") or []
    print(f"All jobs: {len(jobs)}")
    for j in jobs:
        print(f"  {j.get('Code', '?'):40s} | {j.get('State', '?'):10s} | {j.get('Date', '')} {j.get('Time', '')}")

    # Try downloading any completed job matching our table
    if ready := [j for j in jobs if j.get("State") == "Fertig" and KREISE_TABLE in j.get("Code", "")]:
        job_code = ready[0]["Code"]
        print(f"Downloading completed job: {job_code}")
        resp = requests.post(
            f"{REGIO_BASE}/data/resultfile",
            headers=REGIO_HEADERS,
            data={"name": job_code, "compress": "true", "language": "de"},
            timeout=120,
        )

        handle_genesis_response(resp, cache_kreise)

    elif any(j.get("State") == "Wartet" for j in jobs):
        waiting = [j for j in jobs if j.get("State") == "Wartet" and KREISE_TABLE in j.get("Code", "")]
        print(f"{len(waiting)} job(s) still waiting. Re-run this cell in a few minutes.")

    else:
        print("No matching jobs found. Submitting new job...")
        resp = requests.post(
            f"{REGIO_BASE}/data/tablefile",
            headers=REGIO_HEADERS,
            data={
                "name": KREISE_TABLE,
                "area": "all",
                "compress": "true",
                "format": "ffcsv",
                "language": "de",
                "startyear": "1999",
                "endyear": "2025",
                "job": "true",
            },
            timeout=30,
        )
        print(f"  {resp.json().get('Status', {}).get('Content', '')[:150]}")

# Preview if cached
if cache_kreise.exists():
    text = cache_kreise.read_text()
    lines = text.splitlines()
    print(f"{KREISE_TABLE} preview ({len(lines):,} lines):")
    for line in lines[:15]:
        print(f"  {line[:120]}")
    print("...")
    for line in lines[-51:]:
        print(f"  {line[:120]}")
# Out:
# Table 41241-01-03-4: cached (1057 KB)
# 41241-01-03-4 preview (13,048 lines):
#   Tabelle: 41241-01-03-4
#   Erträge ausgewählter landwirtschaftlicher Feldfrüchte -;;;;;;;;;;;;
#   Jahressumme - regionale Tiefe: Kreise und krfr. Städte;;;;;;;;;;;;
#   Erntestatistik;;;;;;;;;;;;
#   Hektarerträge (dt/ha);;;;;;;;;;;;
#   ;;;Feldfruchtarten;Feldfruchtarten;Feldfruchtarten;Feldfruchtarten;Feldfruchtarten;Feldfruchtarten;Feldfruchtarten;Feldf
#   ;;;Winterweizen;Roggen und Wintermenggetreide;Wintergerste;Sommergerste;Hafer;Triticale;Kartoffeln;Zuckerrüben;Winterrap
#   2025;DG;Deutschland;79,0;56,3;78,6;58,2;49,9;63,5;459,6;834,4;36,4;445,8
#   2025;01;  Schleswig-Holstein;90,7;78,1;88,6;60,2;70,5;71,8;385,3;857,1;38,1;457,6
#   2025;01002;      Kiel, kreisfreie Stadt;/;/;/;-;/;-;/;/;/;/
#   2025;01003;      Lübeck, kreisfreie Stadt, Hansestadt;94,0;/;83,3;/;/;/;/;/;30,2;/
#   2025;01004;      Neumünster, kreisfreie Stadt;/;/;/;-;/;/;/;-;/;/
#   2025;01051;      Dithmarschen, Kreis;81,2;83,2;77,6;54,9;77,8;/;404,9;762,3;39,9;413,7
#   2025;01053;      Herzogtum Lauenburg, Kreis;85,9;69,0;83,8;/;55,4;/;469,6;868,0;36,8;464,2
#   2025;01054;      Nordfriesland, Kreis;91,5;83,7;103,0;60,9;58,3;73,8;/;895,3;42,5;455,8
# ...
#   1999;16077;      Altenburger Land, Landkreis;76,5;72,5;74,3;53,5;58,8;70,7;427,4;552,3;40,6;555,8
#   __________
#   "zu ""gesamte Tabelle"":
#   Die Ertragsschätzungen erfolgen von fachkundigen und mit den
#   speziellen Verhältnissen ihres Betriebes bzw. ihres
#   Berichtsbezirks gut vertrauten Berichterstatterinnen und
#   Berichterstattern. Als Berichterstatterinnen und
#   Berichterstatter sind überwiegend Leiterinnen oder Leiter
#   landwirtschaftlicher Betriebe tätig. Bei Getreide,
#   Kartoffeln und Raps erfolgen zusätzlich objektive
#   Ertragsmessungen im Rahmen der ?Besonderen Ernte- und
#   Qualitätsermittlung?. Der ?Besonderen Ernte- und
#   Qualitätsermittlung? liegt ein mathematisches
#   Stichprobenverfahren zu Grunde, das auf die sehr genaue
#   Bestimmung des im Landesdurchschnitt erzielten Ertrags
#   ausgerichtet ist; die Messungen erfolgen dabei auf
#   Flächeneinheiten, die mit Hilfe des Stichprobenverfahrens
#   repräsentativ ausgewählt wurden.
#
#   Eine Dezitonne (dt) entspricht 100 kg.
#
#   Berlin, Bremen, Hamburg: Tabelle liegt nicht vor.
#   Rheinland-Pfalz: Ergebnisse der kreisfreien Städte sind den
#   Landkreisen zugeordnet, die mit ihnen überwiegend räumlich
#   verbunden sind.
#
#   Brandenburg (bis 2009): Ergebnisse der kreisfreien Städte
#   Brandenburg
#   an der Havel und Potsdam sind dem Landkreis
#   Potsdam-Mittelmark zugeordnet.
#
#   zu ""Erträge ausgewählter landwirtschaftlicher Feldfrüchte in
#   dt/ha"":
#   zu ""Roggen einschl. Wintermenggetreide"":
#   bis 2009: Roggen
#   Hessen: ab 1999 einschl. Wintermenggetreide
#
#   zu ""Kartoffeln"":
#   bis 2009: Kartoffeln (mittelfrühe und späte)
#
#   zu ""Zuckerrüben""
#   Schleswig-Holstein 2010: Abweichungen zu anderen
#   Veröffentlichungen ergeben sich ggf. durch nachträgliche
#   Korrekturen.
#
#   zu ""Hafer""
#   Schleswig-Holstein 2011: einschl. Sommermenggetreide"
#   "© Statistische Ämter des Bundes und der Länder, Deutschland, 2026.
#   Dieses Werk ist lizenziert unter der Datenlizenz Deutschland
#   - Namensnennung - Version 2.0."
#   Stand: 07.03.2026 / 22:39:20

# %% [markdown]
# ### Parse & clean Kreise-level ffcsv
#
# Same ffcsv format as the Bundesland table, but with Kreiskennziffer (5-digit AGS code) instead of Bundesland code.

# %% [markdown]
# As of writing, there are 13048 lines in that file, but the CSV table spans only 12945 rows.

# %%
text = cache_kreise.read_text(encoding="utf-8")
lines = text.splitlines()
len(lines)
# Out:
# 13048

# %%
# skipfooter=4 for what Pandas recognizes, in reality there are 50 extra rows, but it fails to parse the remaining 44, hence only 6 to drop.
kreise_df = pd.read_csv(
    cache_kreise,
    sep=";",
    decimal=",",
    header=0,
    skiprows=6,
    skipfooter=4,
    na_values=["/", ".", "-"],
    skipinitialspace=True,
).rename(columns={"Unnamed: 0": "year", "Unnamed: 1": "kreis_code", "Unnamed: 2": "kreis_name"})
# kreise_df["kreis_name"] = kreise_df["kreis_name"].str.strip()
kreise_df
# Out:
# /var/folders/8l/pdw1tpc15616zvq3yj3p1hsh0000gp/T/ipykernel_98549/3413113537.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   kreise_df = pd.read_csv(
#        year kreis_code                            kreis_name  Winterweizen  \
# 0      2025         DG                           Deutschland          79.0
# 1      2025         01                    Schleswig-Holstein          90.7
# 2      2025      01002                Kiel, kreisfreie Stadt           NaN
# 3      2025      01003  Lübeck, kreisfreie Stadt, Hansestadt          94.0
# 4      2025      01004          Neumünster, kreisfreie Stadt           NaN
# ...     ...        ...                                   ...           ...
# 12986  1999      16073        Saalfeld-Rudolstadt, Landkreis          64.9
# 12987  1999      16074                  Saale-Holzland-Kreis          69.8
# 12988  1999      16075                      Saale-Orla-Kreis          68.9
# 12989  1999      16076                      Greiz, Landkreis          72.1
# 12990  1999      16077           Altenburger Land, Landkreis          76.5
#
#        Roggen und Wintermenggetreide  Wintergerste  Sommergerste  Hafer  \
# 0                               56.3          78.6          58.2   49.9
# 1                               78.1          88.6          60.2   70.5
# 2                                NaN           NaN           NaN    NaN
# 3                                NaN          83.3           NaN    NaN
# 4                                NaN           NaN           NaN    NaN
# ...                              ...           ...           ...    ...
# 12986                           55.0          61.8          50.4   58.0
# 12987                           55.0          67.0          52.0   64.6
# 12988                           60.0          67.4          54.3   68.5
# 12989                           68.2          70.0          53.7   56.7
# 12990                           72.5          74.3          53.5   58.8
#
#        Triticale Kartoffeln  Zuckerrüben  Winterraps  Silomais
# 0           63.5      459.6        834.4        36.4     445.8
# 1           71.8      385.3        857.1        38.1     457.6
# 2            NaN        NaN          NaN         NaN       NaN
# 3            NaN        NaN          NaN        30.2       NaN
# 4            NaN        NaN          NaN         NaN       NaN
# ...          ...        ...          ...         ...       ...
# 12986       58.8      340.9          NaN        34.2     413.0
# 12987       62.4      353.3        487.2        40.2     497.0
# 12988       67.2      401.9        530.0        42.1     435.5
# 12989       66.6      342.7        528.5        44.1     496.9
# 12990       70.7      427.4        552.3        40.6     555.8
#
# [12991 rows x 13 columns]

# %%
# SEE https://duckdb.org/docs/stable/data/csv/overview
con.sql(f"""
    drop table if exists kreise_crops_raw;
    create table kreise_crops_raw as
    select trim(columns(*))
    from read_csv(
        "{cache_kreise}",
        skip=6,
        sep=";",
        decimal_separator=",",
        header=true,
        nullstr=["/", "-", ".", '...'],
        all_varchar=true,
        ignore_errors=true,
        store_rejects=true);
""")

# %%
con.sql("""
    alter table kreise_crops_raw rename column "column00" to year;
    alter table kreise_crops_raw rename column "column01" to kreis_code;
    alter table kreise_crops_raw rename column "column02" to kreis_name;
""")

# %%
con.sql("describe kreise_crops_raw")
# Out:
# ┌───────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │          column_name          │ column_type │  null   │   key   │ default │  extra  │
# │            varchar            │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├───────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ year                          │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ kreis_code                    │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ kreis_name                    │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ Winterweizen                  │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ Roggen und Wintermenggetreide │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ Wintergerste                  │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ Sommergerste                  │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ Hafer                         │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ Triticale                     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ Kartoffeln                    │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ Zuckerrüben                   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ Winterraps                    │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ Silomais                      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# └───────────────────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┘
#   13 rows                                                                   6 columns

# %%
# All varchar values in "Kartoffeln" column that can't be coerced to double or decimal ("..." is also a n/a sentinel):
con.sql("""
    select distinct Kartoffeln as raw_val
    from kreise_crops_raw
    where nullif(trim(Kartoffeln), '') is not null
      and (try_cast(replace(Kartoffeln, ',', '.') as double) is null
          or try_cast(replace(Kartoffeln, ',', '.') as decimal) is null)
    order by 1
""")
# Out:
# ┌─────────┐
# │ raw_val │
# │ varchar │
# └─────────┘
#   0 rows

# %%
con.sql("select count(*) from kreise_crops_raw")
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │        12991 │
# └──────────────┘

# %%
con.sql("select * from reject_scans")
# Out:
# ┌─────────┬─────────┬────────────────────────────────┬───────────┬─────────┬─────────┬───────────────────┬───────────┬────────────┬───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬─────────────┬──────────────────┬───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ scan_id │ file_id │           file_path            │ delimiter │  quote  │ escape  │ newline_delimiter │ skip_rows │ has_header │                                                                                                                                                                columns                                                                                                                                                                │ date_format │ timestamp_format │                                                                user_arguments                                                                 │
# │ uint64  │ uint64  │            varchar             │  varchar  │ varchar │ varchar │      varchar      │  uint32   │  boolean   │                                                                                                                                                                varchar                                                                                                                                                                │   varchar   │     varchar      │                                                                    varchar                                                                    │
# ├─────────┼─────────┼────────────────────────────────┼───────────┼─────────┼─────────┼───────────────────┼───────────┼────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────┼──────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      44 │       0 │ _cache/regio_41241-01-03-4.csv │ ;         │ "       │ "       │ \n                │         6 │ true       │ {'column00': 'BIGINT','column01': 'VARCHAR','column02': 'VARCHAR','Winterweizen': 'DOUBLE','Roggen und Wintermenggetreide': 'DOUBLE','Wintergerste': 'DOUBLE','Sommergerste': 'DOUBLE','Hafer': 'DOUBLE','Triticale': 'DOUBLE','Kartoffeln': 'VARCHAR','Zuckerrüben': 'DOUBLE','Winterraps': 'DOUBLE','Silomais': 'DOUBLE'}           │ NULL        │ NULL             │ decimal_separator=',', header=true, ignore_errors=true, nullstr=['/', '-', '.'], sep=';', skip=6, store_rejects=true                          │
# │      58 │       0 │ _cache/regio_41241-01-03-4.csv │ ;         │ "       │ "       │ \n                │         6 │ true       │ {'column00': 'VARCHAR','column01': 'VARCHAR','column02': 'VARCHAR','Winterweizen': 'VARCHAR','Roggen und Wintermenggetreide': 'VARCHAR','Wintergerste': 'VARCHAR','Sommergerste': 'VARCHAR','Hafer': 'VARCHAR','Triticale': 'VARCHAR','Kartoffeln': 'VARCHAR','Zuckerrüben': 'VARCHAR','Winterraps': 'VARCHAR','Silomais': 'VARCHAR'} │ NULL        │ NULL             │ all_varchar=true, decimal_separator=',', header=true, ignore_errors=true, nullstr=['/', '-', '.', '...'], sep=';', skip=6, store_rejects=true │
# │      66 │       0 │ _cache/regio_41241-01-03-4.csv │ ;         │ "       │ "       │ \n                │         6 │ true       │ {'column00': 'VARCHAR','column01': 'VARCHAR','column02': 'VARCHAR','Winterweizen': 'VARCHAR','Roggen und Wintermenggetreide': 'VARCHAR','Wintergerste': 'VARCHAR','Sommergerste': 'VARCHAR','Hafer': 'VARCHAR','Triticale': 'VARCHAR','Kartoffeln': 'VARCHAR','Zuckerrüben': 'VARCHAR','Winterraps': 'VARCHAR','Silomais': 'VARCHAR'} │ NULL        │ NULL             │ all_varchar=true, decimal_separator=',', header=true, ignore_errors=true, nullstr=['/', '-', '.', '...'], sep=';', skip=6, store_rejects=true │
# │      77 │       0 │ _cache/regio_41241-01-03-4.csv │ ;         │ "       │ "       │ \n                │         6 │ true       │ {'column00': 'VARCHAR','column01': 'VARCHAR','column02': 'VARCHAR','Winterweizen': 'VARCHAR','Roggen und Wintermenggetreide': 'VARCHAR','Wintergerste': 'VARCHAR','Sommergerste': 'VARCHAR','Hafer': 'VARCHAR','Triticale': 'VARCHAR','Kartoffeln': 'VARCHAR','Zuckerrüben': 'VARCHAR','Winterraps': 'VARCHAR','Silomais': 'VARCHAR'} │ NULL        │ NULL             │ all_varchar=true, decimal_separator=',', header=true, ignore_errors=true, nullstr=['/', '-', '.', '...'], sep=';', skip=6, store_rejects=true │
# │      79 │       0 │ _cache/regio_41241-01-03-4.csv │ ;         │ "       │ "       │ \n                │         6 │ true       │ {'column00': 'VARCHAR','column01': 'VARCHAR','column02': 'VARCHAR','Winterweizen': 'VARCHAR','Roggen und Wintermenggetreide': 'VARCHAR','Wintergerste': 'VARCHAR','Sommergerste': 'VARCHAR','Hafer': 'VARCHAR','Triticale': 'VARCHAR','Kartoffeln': 'VARCHAR','Zuckerrüben': 'VARCHAR','Winterraps': 'VARCHAR','Silomais': 'VARCHAR'} │ NULL        │ NULL             │ all_varchar=true, decimal_separator=',', header=true, ignore_errors=true, nullstr=['/', '-', '.', '...'], sep=';', skip=6, store_rejects=true │
# └─────────┴─────────┴────────────────────────────────┴───────────┴─────────┴─────────┴───────────────────┴───────────┴────────────┴───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴─────────────┴──────────────────┴───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
con.sql("""
    select * from reject_errors
""")
# Out:
# ┌─────────┬─────────┬────────┬────────────────────┬───────────────┬────────────┬───────────────────────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬──────────────────────────────┬────────────────────────────────────────────────────────────────────────────────────────────┐
# │ scan_id │ file_id │  line  │ line_byte_position │ byte_position │ column_idx │          column_name          │                                                              error_type                                                              │           csv_line           │                                       error_message                                        │
# │ uint64  │ uint64  │ uint64 │       uint64       │    uint64     │   uint64   │            varchar            │ enum('cast', 'missing columns', 'too many columns', 'unquoted value', 'line size over maximum', 'invalid encoding', 'invalid state') │           varchar            │                                          varchar                                           │
# ├─────────┼─────────┼────────┼────────────────────┼───────────────┼────────────┼───────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │      44 │       0 │  12999 │            1080663 │       1080663 │          1 │ column00                      │ CAST                                                                                                                                 │ __________                   │ Error when converting column "column00". Could not convert string "__________" to 'BIGINT' │
# │      44 │       0 │  12999 │            1080663 │       1080673 │          1 │ column01                      │ MISSING COLUMNS                                                                                                                      │ __________                   │ Expected Number of Columns: 13 Found: 1                                                    │
# │      44 │       0 │  12999 │            1080663 │       1080673 │          2 │ column02                      │ MISSING COLUMNS                                                                                                                      │ __________                   │ Expected Number of Columns: 13 Found: 2                                                    │
# │      44 │       0 │  12999 │            1080663 │       1080673 │          3 │ Winterweizen                  │ MISSING COLUMNS                                                                                                                      │ __________                   │ Expected Number of Columns: 13 Found: 3                                                    │
# │      44 │       0 │  12999 │            1080663 │       1080673 │          4 │ Roggen und Wintermenggetreide │ MISSING COLUMNS                                                                                                                      │ __________                   │ Expected Number of Columns: 13 Found: 4                                                    │
# │      44 │       0 │  12999 │            1080663 │       1080673 │          5 │ Wintergerste                  │ MISSING COLUMNS                                                                                                                      │ __________                   │ Expected Number of Columns: 13 Found: 5                                                    │
# │      44 │       0 │  12999 │            1080663 │       1080673 │          6 │ Sommergerste                  │ MISSING COLUMNS                                                                                                                      │ __________                   │ Expected Number of Columns: 13 Found: 6                                                    │
# │      44 │       0 │  12999 │            1080663 │       1080673 │          7 │ Hafer                         │ MISSING COLUMNS                                                                                                                      │ __________                   │ Expected Number of Columns: 13 Found: 7                                                    │
# │      44 │       0 │  12999 │            1080663 │       1080673 │          8 │ Triticale                     │ MISSING COLUMNS                                                                                                                      │ __________                   │ Expected Number of Columns: 13 Found: 8                                                    │
# │      44 │       0 │  12999 │            1080663 │       1080673 │          9 │ Kartoffeln                    │ MISSING COLUMNS                                                                                                                      │ __________                   │ Expected Number of Columns: 13 Found: 9                                                    │
# │       · │       · │    ·   │               ·    │          ·    │          · │     ·                         │        ·                                                                                                                             │     ·                        │                    ·                                                                       │
# │       · │       · │    ·   │               ·    │          ·    │          · │     ·                         │        ·                                                                                                                             │     ·                        │                    ·                                                                       │
# │       · │       · │    ·   │               ·    │          ·    │          · │     ·                         │        ·                                                                                                                             │     ·                        │                    ·                                                                       │
# │      79 │       0 │  13002 │            1082492 │       1082520 │          3 │ Winterweizen                  │ MISSING COLUMNS                                                                                                                      │ Stand: 07.03.2026 / 22:39:20 │ Expected Number of Columns: 13 Found: 3                                                    │
# │      79 │       0 │  13002 │            1082492 │       1082520 │          4 │ Roggen und Wintermenggetreide │ MISSING COLUMNS                                                                                                                      │ Stand: 07.03.2026 / 22:39:20 │ Expected Number of Columns: 13 Found: 4                                                    │
# │      79 │       0 │  13002 │            1082492 │       1082520 │          5 │ Wintergerste                  │ MISSING COLUMNS                                                                                                                      │ Stand: 07.03.2026 / 22:39:20 │ Expected Number of Columns: 13 Found: 5                                                    │
# │      79 │       0 │  13002 │            1082492 │       1082520 │          6 │ Sommergerste                  │ MISSING COLUMNS                                                                                                                      │ Stand: 07.03.2026 / 22:39:20 │ Expected Number of Columns: 13 Found: 6                                                    │
# │      79 │       0 │  13002 │            1082492 │       1082520 │          7 │ Hafer                         │ MISSING COLUMNS                                                                                                                      │ Stand: 07.03.2026 / 22:39:20 │ Expected Number of Columns: 13 Found: 7                                                    │
# │      79 │       0 │  13002 │            1082492 │       1082520 │          8 │ Triticale                     │ MISSING COLUMNS                                                                                                                      │ Stand: 07.03.2026 / 22:39:20 │ Expected Number of Columns: 13 Found: 8                                                    │
# │      79 │       0 │  13002 │            1082492 │       1082520 │          9 │ Kartoffeln                    │ MISSING COLUMNS                                                                                                                      │ Stand: 07.03.2026 / 22:39:20 │ Expected Number of Columns: 13 Found: 9                                                    │
# │      79 │       0 │  13002 │            1082492 │       1082520 │         10 │ Zuckerrüben                   │ MISSING COLUMNS                                                                                                                      │ Stand: 07.03.2026 / 22:39:20 │ Expected Number of Columns: 13 Found: 10                                                   │
# │      79 │       0 │  13002 │            1082492 │       1082520 │         11 │ Winterraps                    │ MISSING COLUMNS                                                                                                                      │ Stand: 07.03.2026 / 22:39:20 │ Expected Number of Columns: 13 Found: 11                                                   │
# │      79 │       0 │  13002 │            1082492 │       1082520 │         12 │ Silomais                      │ MISSING COLUMNS                                                                                                                      │ Stand: 07.03.2026 / 22:39:20 │ Expected Number of Columns: 13 Found: 12                                                   │
# └─────────┴─────────┴────────┴────────────────────┴───────────────┴────────────┴───────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────┘
#   244 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                  10 columns

# %%
con.sql("""
    unpivot kreise_crops_raw on columns(* exclude (year, kreis_code, kreis_name))
    into name crop_name
         value yield_dt_ha_str
""")
# Out:
# ┌─────────┬────────────┬───────────────────────────────┬───────────────────────────────┬─────────────────┐
# │  year   │ kreis_code │          kreis_name           │           crop_name           │ yield_dt_ha_str │
# │ varchar │  varchar   │            varchar            │            varchar            │     varchar     │
# ├─────────┼────────────┼───────────────────────────────┼───────────────────────────────┼─────────────────┤
# │ 2025    │ DG         │ Deutschland                   │ Winterweizen                  │ 79,0            │
# │ 2025    │ DG         │ Deutschland                   │ Roggen und Wintermenggetreide │ 56,3            │
# │ 2025    │ DG         │ Deutschland                   │ Wintergerste                  │ 78,6            │
# │ 2025    │ DG         │ Deutschland                   │ Sommergerste                  │ 58,2            │
# │ 2025    │ DG         │ Deutschland                   │ Hafer                         │ 49,9            │
# │ 2025    │ DG         │ Deutschland                   │ Triticale                     │ 63,5            │
# │ 2025    │ DG         │ Deutschland                   │ Kartoffeln                    │ 459,6           │
# │ 2025    │ DG         │ Deutschland                   │ Zuckerrüben                   │ 834,4           │
# │ 2025    │ DG         │ Deutschland                   │ Winterraps                    │ 36,4            │
# │ 2025    │ DG         │ Deutschland                   │ Silomais                      │ 445,8           │
# │  ·      │ ·          │      ·                        │   ·                           │  ·              │
# │  ·      │ ·          │      ·                        │   ·                           │  ·              │
# │  ·      │ ·          │      ·                        │   ·                           │  ·              │
# │ 2021    │ 06534      │ Marburg-Biedenkopf, Landkreis │ Hafer                         │ 50,1            │
# │ 2021    │ 06534      │ Marburg-Biedenkopf, Landkreis │ Triticale                     │ 70,5            │
# │ 2021    │ 06534      │ Marburg-Biedenkopf, Landkreis │ Kartoffeln                    │ 347,8           │
# │ 2021    │ 06534      │ Marburg-Biedenkopf, Landkreis │ Winterraps                    │ 37,9            │
# │ 2021    │ 06534      │ Marburg-Biedenkopf, Landkreis │ Silomais                      │ 552,8           │
# │ 2021    │ 06535      │ Vogelsbergkreis               │ Winterweizen                  │ 67,4            │
# │ 2021    │ 06535      │ Vogelsbergkreis               │ Roggen und Wintermenggetreide │ 63,0            │
# │ 2021    │ 06535      │ Vogelsbergkreis               │ Wintergerste                  │ 65,9            │
# │ 2021    │ 06535      │ Vogelsbergkreis               │ Sommergerste                  │ 53,8            │
# │ 2021    │ 06535      │ Vogelsbergkreis               │ Hafer                         │ 55,4            │
# └─────────┴────────────┴───────────────────────────────┴───────────────────────────────┴─────────────────┘
#   ? rows (>9999 rows, 20 shown)                                                                5 columns

# %%
con.sql("select count(*) from kreise_crops_raw")
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │        12991 │
# └──────────────┘

# %%
con.sql("""
    select count(*)
    from (unpivot kreise_crops_raw
          on columns(* exclude (year, kreis_code, kreis_name))
          into name crop_name value yield_dt_ha_str)
""")
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │        89830 │
# └──────────────┘

# %%
# Now parse values as decimal
con.sql("""
    -- Create unpivoted table (columns -> rows):
    create or replace table kreise_crops as
    select year, kreis_code, kreis_name, crop_name
         , try_cast(replace(trim(yield_dt_ha_str), ',', '.') as decimal(8,1)) as yield_dt_ha_dec
    from (unpivot kreise_crops_raw
          on columns(* exclude (year, kreis_code, kreis_name))
          into name crop_name value yield_dt_ha_str);
    -- Sample 10 rows to peek into the result:
    select * from kreise_crops using sample 10 rows;
""")
# Out:
# ┌─────────┬────────────┬──────────────────────────────────┬───────────────────────────────┬─────────────────┐
# │  year   │ kreis_code │            kreis_name            │           crop_name           │ yield_dt_ha_dec │
# │ varchar │  varchar   │             varchar              │            varchar            │  decimal(8,1)   │
# ├─────────┼────────────┼──────────────────────────────────┼───────────────────────────────┼─────────────────┤
# │ 2021    │ 032        │ Hannover, Statistische Region    │ Hafer                         │            49.1 │
# │ 2021    │ 14         │ Sachsen                          │ Zuckerrüben                   │           823.7 │
# │ 2019    │ 03251      │ Diepholz, Landkreis              │ Roggen und Wintermenggetreide │            57.3 │
# │ 2016    │ 03154      │ Helmstedt, Landkreis             │ Winterraps                    │            38.4 │
# │ 2015    │ 01054      │ Nordfriesland, Kreis             │ Winterraps                    │            42.7 │
# │ 2014    │ 12070      │ Prignitz, Landkreis              │ Triticale                     │            62.6 │
# │ 2013    │ 03361      │ Verden, Landkreis                │ Winterraps                    │            40.0 │
# │ 2013    │ 097        │ Schwaben, Regierungsbezirk       │ Zuckerrüben                   │           705.4 │
# │ 2012    │ 13075      │ Vorpommern-Greifswald, Landkreis │ Winterweizen                  │            73.3 │
# │ 2011    │ 084        │ Tübingen, Regierungsbezirk       │ Zuckerrüben                   │           776.7 │
# └─────────┴────────────┴──────────────────────────────────┴───────────────────────────────┴─────────────────┘
#   10 rows                                                                                         5 columns

# %%
con.sql("select count(*) from kreise_crops")
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │        89830 │
# └──────────────┘

# %%
con.sql("describe kreise_crops")
# Out:
# ┌─────────────────┬──────────────┬─────────┬─────────┬─────────┬─────────┐
# │   column_name   │ column_type  │  null   │   key   │ default │  extra  │
# │     varchar     │   varchar    │ varchar │ varchar │ varchar │ varchar │
# ├─────────────────┼──────────────┼─────────┼─────────┼─────────┼─────────┤
# │ year            │ VARCHAR      │ YES     │ NULL    │ NULL    │ NULL    │
# │ kreis_code      │ VARCHAR      │ YES     │ NULL    │ NULL    │ NULL    │
# │ kreis_name      │ VARCHAR      │ YES     │ NULL    │ NULL    │ NULL    │
# │ crop_name       │ VARCHAR      │ YES     │ NULL    │ NULL    │ NULL    │
# │ yield_dt_ha_dec │ DECIMAL(8,1) │ YES     │ NULL    │ NULL    │ NULL    │
# └─────────────────┴──────────────┴─────────┴─────────┴─────────┴─────────┘

# %%
# Unpivot/melt
crop_kreise_df = kreise_df.melt(
    id_vars=["year", "kreis_code", "kreis_name"],
    value_vars=kreise_df.columns[3:],
    var_name="crop_name",
    value_name="yield_dt_ha_str",
)
crop_kreise_df
# crop_kreise_df[crop_kreise_df["kreis_code"].str.startswith("01") & (crop_kreise_df["year"] == 2025)]
# Out:
#         year kreis_code                            kreis_name     crop_name  \
# 0       2025         DG                           Deutschland  Winterweizen
# 1       2025         01                    Schleswig-Holstein  Winterweizen
# 2       2025      01002                Kiel, kreisfreie Stadt  Winterweizen
# 3       2025      01003  Lübeck, kreisfreie Stadt, Hansestadt  Winterweizen
# 4       2025      01004          Neumünster, kreisfreie Stadt  Winterweizen
# ...      ...        ...                                   ...           ...
# 129905  1999      16073        Saalfeld-Rudolstadt, Landkreis      Silomais
# 129906  1999      16074                  Saale-Holzland-Kreis      Silomais
# 129907  1999      16075                      Saale-Orla-Kreis      Silomais
# 129908  1999      16076                      Greiz, Landkreis      Silomais
# 129909  1999      16077           Altenburger Land, Landkreis      Silomais
#
#        yield_dt_ha_str
# 0                 79.0
# 1                 90.7
# 2                  NaN
# 3                 94.0
# 4                  NaN
# ...                ...
# 129905           413.0
# 129906           497.0
# 129907           435.5
# 129908           496.9
# 129909           555.8
#
# [129910 rows x 5 columns]

# %%
con.sql("""
    select count(*)
    from crop_kreise_df d
    where not exists (select 1 from kreise_crops t where t.year = d.year and t.kreis_code = d.kreis_code and t.crop_name = d.crop_name);
""")
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │        40080 │
# └──────────────┘

# %%
129910 - 40080
# Out:
# 89830

# %%
# Assert all values are null
con.sql("""
    select sum(case when d.yield_dt_ha_str is null then 0 else 1 end)
    from crop_kreise_df d
    -- group by t.year, t.kreis_code, t.crop_name
    where not exists (select 1 from kreise_crops t where t.year = d.year and t.kreis_code = d.kreis_code and t.crop_name = d.crop_name);
""")
# Out:
# ┌───────────────────────────────────────────────────────────────────┐
# │ sum(CASE  WHEN ((d.yield_dt_ha_str IS NULL)) THEN (0) ELSE 1 END) │
# │                              int128                               │
# ├───────────────────────────────────────────────────────────────────┤
# │                                                                 1 │
# └───────────────────────────────────────────────────────────────────┘

# %%
con.sql("""
    select *
    from crop_kreise_df d
    -- group by t.year, t.kreis_code, t.crop_name
    where not exists (select 1 from kreise_crops t where t.year = d.year and t.kreis_code = d.kreis_code and t.crop_name = d.crop_name)
      and d.yield_dt_ha_str is not null
""")
# Out:
# ┌───────┬────────────┬──────────────────────┬────────────┬─────────────────┐
# │ year  │ kreis_code │      kreis_name      │ crop_name  │ yield_dt_ha_str │
# │ int64 │  varchar   │       varchar        │  varchar   │     varchar     │
# ├───────┼────────────┼──────────────────────┼────────────┼─────────────────┤
# │  2016 │ 08215      │ Karlsruhe, Landkreis │ Kartoffeln │ ...             │
# └───────┴────────────┴──────────────────────┴────────────┴─────────────────┘

# %% [markdown]
# This is exactly the single `...` n/a sentinel. So, in fact, by coercing to decimal, we dropped only n/a values.
# The deviation by 40080 total count fewer rows in the DuckDB table vs the Pandas data frame is due to that `...` n/a sentinel. In other words, if we adjust the Pandas `read_csv` call to include that ellipsis `...` in `na_values`, there the deviation will be exactly all n/a values or `nulls` in DuckDB.
#
# This raises two questions:
#
# 1. Should we enhance the Pandas CSV parser configuration? -> No, we'll just continue in DuckDB.
# 2. Should we retain all `n/a`s as `null`s in DuckDB? -> Yes, this maintains authenticity and enables joins by `kreis_code` and `year`.
#
# So, let's redefine the table `kreise_crops`

# %%
# Now parse values as decimal, while retaining the nulls.
# SEE https://duckdb.org/docs/stable/sql/statements/unpivot
# NOTE: Must use standard SQL unpivot to enable `include nulls`
con.sql("""
    -- Create unpivoted table (columns -> rows):
    create or replace table kreise_crops as
    --
    with unpivoted as (
        from kreise_crops_raw unpivot include nulls (-- standard SQL unpivot statement
            yield_dt_ha_str
            for crop_name in (columns(* exclude (year, kreis_code, kreis_name))))
    )
    select year, kreis_code, kreis_name, crop_name
         , try_cast(replace(trim(yield_dt_ha_str), ',', '.') as decimal(8,1)) as yield_dt_ha_dec
    from unpivoted;
    -- Sample 10 rows to peek into the result:
    select * from kreise_crops using sample 10 rows;
""")
# Out:
# ┌─────────┬────────────┬───────────────────────────────────┬───────────────────────────────┬─────────────────┐
# │  year   │ kreis_code │            kreis_name             │           crop_name           │ yield_dt_ha_dec │
# │ varchar │  varchar   │              varchar              │            varchar            │  decimal(8,1)   │
# ├─────────┼────────────┼───────────────────────────────────┼───────────────────────────────┼─────────────────┤
# │ 2025    │ 05370      │ Heinsberg, Kreis                  │ Winterweizen                  │           106.7 │
# │ 2024    │ 05119      │ Oberhausen, kreisfreie Stadt      │ Triticale                     │            NULL │
# │ 2023    │ 05112      │ Duisburg, kreisfreie Stadt        │ Winterweizen                  │            NULL │
# │ 2022    │ 065        │ Gießen, Regierungsbezirk          │ Wintergerste                  │            72.4 │
# │ 2021    │ 05111      │ Düsseldorf, kreisfreie Stadt      │ Roggen und Wintermenggetreide │            NULL │
# │ 2021    │ 09279      │ Dingolfing-Landau, Landkreis      │ Hafer                         │            27.2 │
# │ 2020    │ 07211      │ Trier, kreisfreie Stadt           │ Triticale                     │            NULL │
# │ 2020    │ 09178      │ Freising, Landkreis               │ Hafer                         │            53.9 │
# │ 2019    │ 094        │ Oberfranken, Regierungsbezirk     │ Winterweizen                  │            58.7 │
# │ 2019    │ 16066      │ Schmalkalden-Meiningen, Landkreis │ Sommergerste                  │            46.4 │
# └─────────┴────────────┴───────────────────────────────────┴───────────────────────────────┴─────────────────┘
#   10 rows                                                                                          5 columns

# %%
con.sql("select count(*) from kreise_crops")
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │       129910 │
# └──────────────┘

# %% [markdown]
# ### Mapping Kreise Codes to NUTS Codes

# %% [markdown]
# Now we only need to fold ("pivot") the country and Bundeslaender (NUTS-0, NUTS-1, NUTS-2)

# %%
con.sql("""
    select distinct kreis_code, kreis_name, v.bundesland_code, n.nuts_id as nuts1
    from kreise_crops
    left join verify_df v on v.bundesland_code = substr(kreis_code, 0, 3)
    left join nuts1_names n on n.NUTS_ID = v.nuts1_id
    where strlen(kreis_code) < 5
    order by kreis_code
""")
# Out:
# ┌────────────┬───────────────────────────────────┬─────────────────┬─────────┐
# │ kreis_code │            kreis_name             │ bundesland_code │  nuts1  │
# │  varchar   │              varchar              │     varchar     │ varchar │
# ├────────────┼───────────────────────────────────┼─────────────────┼─────────┤
# │ 01         │ Schleswig-Holstein                │ 01              │ DEF     │
# │ 02         │ Hamburg                           │ NULL            │ NULL    │
# │ 03         │ Niedersachsen                     │ 03              │ DE9     │
# │ 031        │ Braunschweig, Statistische Region │ 03              │ DE9     │
# │ 032        │ Hannover, Statistische Region     │ 03              │ DE9     │
# │ 033        │ Lüneburg, Statistische Region     │ 03              │ DE9     │
# │ 034        │ Weser-Ems, Statistische Region    │ 03              │ DE9     │
# │ 04         │ Bremen                            │ NULL            │ NULL    │
# │ 05         │ Nordrhein-Westfalen               │ 05              │ DEA     │
# │ 051        │ Düsseldorf, Regierungsbezirk      │ 05              │ DEA     │
# │  ·         │             ·                     │ ·               │  ·      │
# │  ·         │             ·                     │ ·               │  ·      │
# │  ·         │             ·                     │ ·               │  ·      │
# │ 143        │ Leipzig, Regierungsbezirk         │ 14              │ DED     │
# │ 145        │ Chemnitz, Statistische Region     │ 14              │ DED     │
# │ 146        │ Dresden, Statistische Region      │ 14              │ DED     │
# │ 147        │ Leipzig, Statistische Region      │ 14              │ DED     │
# │ 15         │ Sachsen-Anhalt                    │ 15              │ DEE     │
# │ 151        │ Dessau, Statistische Region       │ 15              │ DEE     │
# │ 152        │ Halle, Statistische Region        │ 15              │ DEE     │
# │ 153        │ Magdeburg, Statistische Region    │ 15              │ DEE     │
# │ 16         │ Thüringen                         │ 16              │ DEG     │
# │ DG         │ Deutschland                       │ NULL            │ NULL    │
# └────────────┴───────────────────────────────────┴─────────────────┴─────────┘
#   52 rows (20 shown)                                               4 columns

# %%
# Count distinct Kreise by length of their identifier:
con.sql("""
select
    (select count(distinct kreis_code) from kreise_crops where strlen(kreis_code) = 1) as len_1,
    (select count(distinct kreis_code) from kreise_crops where strlen(kreis_code) = 2) as len_2,
    (select count(distinct kreis_code) from kreise_crops where strlen(kreis_code) = 3) as len_3,
    (select count(distinct kreis_code) from kreise_crops where strlen(kreis_code) = 4) as len_4,
    (select count(distinct kreis_code) from kreise_crops where strlen(kreis_code) = 5) as len_5,
    (select count(distinct kreis_code) from kreise_crops where strlen(kreis_code) = 7) as len_6,
    (select count(distinct kreis_code) from kreise_crops where strlen(kreis_code) = 7) as len_7,
    (select count(distinct kreis_code) from kreise_crops where strlen(kreis_code) = 8) as len_8,
    (select count(distinct kreis_code) from kreise_crops where strlen(kreis_code) = 9) as len_9,
    (select count(distinct kreis_code) from kreise_crops where strlen(kreis_code) = 10) as len_10,
""")
# Out:
# ┌───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬────────┐
# │ len_1 │ len_2 │ len_3 │ len_4 │ len_5 │ len_6 │ len_7 │ len_8 │ len_9 │ len_10 │
# │ int64 │ int64 │ int64 │ int64 │ int64 │ int64 │ int64 │ int64 │ int64 │ int64  │
# ├───────┼───────┼───────┼───────┼───────┼───────┼───────┼───────┼───────┼────────┤
# │     0 │    17 │    35 │     0 │   471 │     0 │     0 │    15 │     0 │      0 │
# └───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴────────┘

# %%
con.sql("""
    select distinct kreis_code, kreis_name
    from kreise_crops
    where strlen(kreis_code) = 8
""")
# Out:
# ┌────────────┬───────────────────────────────────┐
# │ kreis_code │            kreis_name             │
# │  varchar   │              varchar              │
# ├────────────┼───────────────────────────────────┤
# │ 11001001   │ Berlin-Mitte                      │
# │ 11004004   │ Berlin-Charlottenburg-Wilmersdorf │
# │ 11005005   │ Berlin-Spandau                    │
# │ 11008008   │ Berlin-Neukölln                   │
# │ 11011011   │ Berlin-Lichtenberg                │
# │ 05334002   │ Aachen, kreisfreie Stadt          │
# │ 03241001   │ Hannover, Landeshauptstadt        │
# │ 11003003   │ Berlin-Pankow                     │
# │ 11006006   │ Berlin-Steglitz-Zehlendorf        │
# │ 11002002   │ Berlin-Friedrichshain-Kreuzberg   │
# │ 11009009   │ Berlin-Treptow-Köpenick           │
# │ 11007007   │ Berlin-Tempelhof-Schöneberg       │
# │ 11010010   │ Berlin-Marzahn-Hellersdorf        │
# │ 11012012   │ Berlin-Reinickendorf              │
# │ 10041100   │ Saarbrücken, Landeshauptstadt     │
# └────────────┴───────────────────────────────────┘
#   15 rows                              2 columns

# %% [markdown]
# So these are rather special cases of Berlin's Bezirke, Aachen, Hannover and Saarbruecken as some Bundesland capitals.
# It is most likely that for these entities, the crop yields are n/a. Let's check.

# %%
con.sql("""
    select kreis_code, kreis_name
         , sum(yield_dt_ha_dec)
    from kreise_crops
    where strlen(kreis_code) = 8
    group by 1, 2
    order by 1
""")
# Out:
# ┌────────────┬───────────────────────────────────┬──────────────────────┐
# │ kreis_code │            kreis_name             │ sum(yield_dt_ha_dec) │
# │  varchar   │              varchar              │    decimal(38,1)     │
# ├────────────┼───────────────────────────────────┼──────────────────────┤
# │ 03241001   │ Hannover, Landeshauptstadt        │                 NULL │
# │ 05334002   │ Aachen, kreisfreie Stadt          │              18246.7 │
# │ 10041100   │ Saarbrücken, Landeshauptstadt     │                 NULL │
# │ 11001001   │ Berlin-Mitte                      │                 NULL │
# │ 11002002   │ Berlin-Friedrichshain-Kreuzberg   │                 NULL │
# │ 11003003   │ Berlin-Pankow                     │                 NULL │
# │ 11004004   │ Berlin-Charlottenburg-Wilmersdorf │                 NULL │
# │ 11005005   │ Berlin-Spandau                    │                 NULL │
# │ 11006006   │ Berlin-Steglitz-Zehlendorf        │                 NULL │
# │ 11007007   │ Berlin-Tempelhof-Schöneberg       │                 NULL │
# │ 11008008   │ Berlin-Neukölln                   │                 NULL │
# │ 11009009   │ Berlin-Treptow-Köpenick           │                 NULL │
# │ 11010010   │ Berlin-Marzahn-Hellersdorf        │                 NULL │
# │ 11011011   │ Berlin-Lichtenberg                │                 NULL │
# │ 11012012   │ Berlin-Reinickendorf              │                 NULL │
# └────────────┴───────────────────────────────────┴──────────────────────┘
#   15 rows                                                     3 columns

# %% [markdown]
# Ok, so only 05334002 - "Aachen, kreisfreie Stadt" has valid crop yield values. We could check its fraction of nulls. But we can already see that it's a Kreis we must take into account. Therefore, we'll need to take care of 8-digit `kreis_code`s too.

# %%
# TODO: nuts0, nuts2, nuts3
con.sql("""
    -- A utility view until we merge with nuts2 and nuts3
    create or replace view vw_kreise_crops_with_nuts1 as
    select columns(k.*), v.bundesland_code, n.nuts_id nuts1
         -- NUTS-0: Country
         , case when strlen(kreis_code) = 2 and kreis_code = 'DG' then true else false end as is_country
         -- NUTS-1: Bundesland
         , case when strlen(kreis_code) = 2 and kreis_code <> 'DG' then true else false end as is_bundesland
         -- NUTS-2: region/Regierungsbezirk
         , case when strlen(kreis_code) = 3 then true else false end as is_region
         -- NUTS-3: granular- 5-digit Kreise
         , case when strlen(kreis_code) = 5 then true else false end as is_kreis
         -- NUTS-3: 8-digit Kreise
         , case when strlen(kreis_code) = 8 then true else false end as is_kreis_8
         -- Other: unexpected change in upstream data, flag
         , case when strlen(kreis_code) not in (2,3,5,8) then true else false end as is_unexpected_kreis_code
    from kreise_crops k
    left join verify_df v on v.bundesland_code = substr(kreis_code, 0, 3)
    left join nuts1_names n on n.NUTS_ID = v.nuts1_id
    order by kreis_code, year;
    -- Sample 10 rows:
    select * from vw_kreise_crops_with_nuts1
    using sample 10 rows;
""")
# Out:
# ┌─────────┬────────────┬───────────────────────────────┬───────────────────────────────┬─────────────────┬─────────────────┬─────────┬────────────┬───────────────┬───────────┬──────────┬────────────┬──────────────────────────┐
# │  year   │ kreis_code │          kreis_name           │           crop_name           │ yield_dt_ha_dec │ bundesland_code │  nuts1  │ is_country │ is_bundesland │ is_region │ is_kreis │ is_kreis_8 │ is_unexpected_kreis_code │
# │ varchar │  varchar   │            varchar            │            varchar            │  decimal(8,1)   │     varchar     │ varchar │  boolean   │    boolean    │  boolean  │ boolean  │  boolean   │         boolean          │
# ├─────────┼────────────┼───────────────────────────────┼───────────────────────────────┼─────────────────┼─────────────────┼─────────┼────────────┼───────────────┼───────────┼──────────┼────────────┼──────────────────────────┤
# │ 2024    │ 05566      │ Steinfurt, Kreis              │ Winterraps                    │            NULL │ 05              │ DEA     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 2002    │ 05119      │ Oberhausen, kreisfreie Stadt  │ Hafer                         │            48.5 │ 05              │ DEA     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 2006    │ 03353      │ Harburg, Landkreis            │ Roggen und Wintermenggetreide │            56.0 │ 03              │ DE9     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 2011    │ 05315      │ Köln, kreisfreie Stadt        │ Triticale                     │            53.4 │ 05              │ DEA     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 2015    │ 16052      │ Gera, kreisfreie Stadt        │ Winterraps                    │            45.0 │ 16              │ DEG     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 2008    │ 05554      │ Borken, Kreis                 │ Winterweizen                  │            86.0 │ 05              │ DEA     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 2006    │ 032        │ Hannover, Statistische Region │ Triticale                     │            66.9 │ 03              │ DE9     │ false      │ false         │ true      │ false    │ false      │ false                    │
# │ 2009    │ 05334002   │ Aachen, kreisfreie Stadt      │ Winterraps                    │            NULL │ 05              │ DEA     │ false      │ false         │ false     │ false    │ true       │ false                    │
# │ 2021    │ 03462      │ Wittmund, Landkreis           │ Winterweizen                  │            71.8 │ 03              │ DE9     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 2018    │ 05911      │ Bochum, kreisfreie Stadt      │ Hafer                         │            NULL │ 05              │ DEA     │ false      │ false         │ false     │ true     │ false      │ false                    │
# └─────────┴────────────┴───────────────────────────────┴───────────────────────────────┴─────────────────┴─────────────────┴─────────┴────────────┴───────────────┴───────────┴──────────┴────────────┴──────────────────────────┘
#   10 rows                                                                                                                                                                                                             13 columns

# %% [markdown]
# #### Kreise -> NUTS-2

# %% [markdown]
# Check what we have for NUTS-2 and NUTS-3 from the earlier EDA on NUTS data. Goal is to obtain a single table with all Kreis-level data and NUTS keys for aggregation - by merging the DB view above with the NUTS-2 and NUTS-3 while avoiding overly complex query structure. In a synthesis follow-up step, we'll craete a table with Bundesland-level crop data and with Kreis-level crop data, both with NUTS ids as keys for easy joining, windowing by groups, and aggregating.

# %%
con.sql("show tables")
# Out:
# ┌───────────────────────────┐
# │           name            │
# │          varchar          │
# ├───────────────────────────┤
# │ data_source_registry      │
# │ dwd_stations              │
# │ dwd_stations_nuts3        │
# │ kreise_crops              │
# │ kreise_crops_raw          │
# │ nuts0                     │
# │ nuts1                     │
# │ nuts1_names               │
# │ nuts2                     │
# │ nuts3                     │
# │ nuts_hierarchy            │
# │ reject_errors             │
# │ reject_scans              │
# │ verify_df                 │
# │ vw_kreise_crops_not_in_df │
# │ yields_bundesland         │
# └───────────────────────────┘
#            16 rows

# %%
con.sql("""
    describe nuts2
""")
# FIXME: MOUNT_TYPE   │ DOUBLE <- must be INTEGER like in the others (same schema)
# Out:
# ┌──────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │ column_name  │ column_type │  null   │   key   │ default │  extra  │
# │   varchar    │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├──────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ NUTS_ID      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ LEVL_CODE    │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ CNTR_CODE    │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ NAME_LATN    │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ NUTS_NAME    │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ MOUNT_TYPE   │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ URBN_TYPE    │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ COAST_TYPE   │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ country_code │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ nuts1_code   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ nuts2_code   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ geometry     │ GEOMETRY    │ YES     │ NULL    │ NULL    │ NULL    │
# └──────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┘
#   12 rows                                                  6 columns

# %%
con.sql("select * from nuts2 using sample 10 rows")
# Out:
# ┌─────────┬───────────┬───────────┬────────────────────────────┬────────────────────────────┬────────────┬───────────┬────────────┬──────────────┬────────────┬────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ NUTS_ID │ LEVL_CODE │ CNTR_CODE │         NAME_LATN          │         NUTS_NAME          │ MOUNT_TYPE │ URBN_TYPE │ COAST_TYPE │ country_code │ nuts1_code │ nuts2_code │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         geometry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         │
# │ varchar │   int32   │  varchar  │          varchar           │          varchar           │   double   │   int32   │   int32    │   varchar    │  varchar   │  varchar   │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         geometry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         │
# ├─────────┼───────────┼───────────┼────────────────────────────┼────────────────────────────┼────────────┼───────────┼────────────┼──────────────┼────────────┼────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ BE32    │         2 │ BE        │ Prov. Hainaut              │ Prov. Hainaut              │        0.0 │         0 │          0 │ BE           │ BE3        │ BE32       │ MULTIPOLYGON (((3.460305500000061 50.76589899900006, 3.541272500000048 50.733700499000065, 3.775676500000031 50.747892499000045, 3.815390500000035 50.750724999000056, 3.895736500000055 50.73294449900004, 3.949402108000072 50.691571880000026, 4.100483 50.70595549900003, 4.12615044000006 50.686742680000066, 4.247219500000028 50.596118999000055, 4.33964850600006 50.58105556600003, 4.577538 50.54228599900006, 4.585938980000037 50.39707601100008, 4.588662500000055 50.321315999000035, 4.474987 50.32760999900006, 4.336552463000032 50.250557066000056, 4.432494 49.94161599900008, 4.233133 49.95782849900007, 4.140853 49.97875999900003, 4.206924001000061 50.079774446000044, 4.185827248000066 50.237258860000054, 4.053077336000058 50.338948009000035, 4.027774500000021 50.35833049900003, 3.71703122100007 50.32705652400006, 3.67326848600004 50.39707601100008, 3.65551 50.46173549900004, 3.615081500000031 50.490398999000035, 3.549289543000043 50.49680294900003, 3.310992605000024 50.52240952600005, 3.245294 50.713009499000066, 3.176996 50.75616449900008, 3.277564853000058 50.757185838000055, 3.324118 50.72230899900006, 3.460305500000061 50.76589899900006)), ((3.018708500000059 50.773532999000054, 2.863276 50.70834349900008, 2.856343546000062 50.74538030400004, 2.958764785000028 50.797896552000054, 3.018708500000059 50.773532999000054)))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             │
# │ DK02    │         2 │ DK        │ Sjælland                   │ Sjælland                   │        0.0 │         0 │          0 │ DK           │ DK0        │ DK02       │ POLYGON ((11.715843738000046 55.915201522000075, 11.788112633000026 55.661185673000034, 11.875297500000045 55.737655999000026, 11.980778500000042 55.73012299900006, 12.016773099000034 55.694755007000026, 12.083868721000044 55.69571487400003, 12.089012160000038 55.78048899800007, 12.250787500000058 55.70841399900007, 12.16914636000007 55.63094085500006, 12.363471 55.59380699900004, 12.224427856000034 55.51702122900008, 12.219570500000032 55.425061999000036, 12.422042600000054 55.31494565500003, 12.16314961300003 55.18895524200008, 12.156487678000076 55.09740217700005, 12.255582184000048 55.074614448000034, 12.266247019000048 54.99641042400003, 12.414777755000046 55.01021306300004, 12.454425292000053 54.96497197700006, 12.228167547000055 54.885642895000046, 12.02914495400006 54.733865252000044, 11.951297276000048 54.60267112400004, 11.472151835000034 54.61763688100007, 11.015631453000026 54.781180506000055, 11.027817822000031 54.88358591000008, 11.110781522000025 54.938327429000026, 11.275420760000031 54.94123818600008, 11.537592079000035 54.840261432000034, 11.938459504000036 54.95974217300005, 11.675769186000025 55.171810838000056, 11.273425668000073 55.22821342900005, 11.063762695000037 55.71397612100003, 11.29177665800006 55.75739456800005, 11.645415413000023 55.94753457400003, 11.715843738000046 55.915201522000075))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             │
# │ DE94    │         2 │ DE        │ Weser-Ems                  │ Weser-Ems                  │        0.0 │         0 │          0 │ DE           │ DE9        │ DE94       │ MULTIPOLYGON (((7.996700715000031 53.70301416500007, 8.091291 53.63810899900005, 8.154662435000034 53.53596516600004, 8.061327 53.505956999000034, 8.195555 53.40917149900008, 8.296486282000046 53.454216882000026, 8.244817410000053 53.544403568000064, 8.288529956000048 53.59959849900008, 8.554898 53.525130999000055, 8.492652 53.47241999900007, 8.499987500000032 53.36684799900007, 8.485330500000032 53.22711999900008, 8.654898500000058 53.10886449900005, 8.711424 53.04462999900005, 8.657161 53.00899449900004, 8.65123197400004 52.87526782400005, 8.459277500000042 52.80105599900003, 8.448298075000025 52.739083203000064, 8.314194198000052 52.66991500700004, 8.308324 52.499111999000036, 8.297213500000055 52.45649799900008, 8.466186500000049 52.26761399900005, 8.410586500000022 52.11511499900007, 8.096448 52.05714499900006, 7.885159 52.08330249900007, 7.990631608000058 52.12791353800003, 7.924675439000055 52.20936213900006, 7.956465 52.27249049900007, 7.964625500000068 52.32485849900007, 7.608038500000021 52.47401599900007, 7.540665789000059 52.36826139100003, 7.317481 52.280271999000036, 7.099149 52.24305849900003, 7.065685 52.24137299900008, 7.009998916000029 52.43915720700005, 6.697865500000034 52.486285999000074, 6.70973250000003 52.627823499000044, 7.006229500000074 52.63876299900005, 7.092692 52.83820099900004, 7.197102208000047 52.981636741000045, 7.202794500000039 53.11328149900004, 7.217469140000048 53.20144491500008, 7.208935 53.24306449900007, 7.2643 53.325526499000034, 7.044732475000046 53.33721088300007, 6.999446500000033 53.35988749900008, 7.11351088300006 53.583731630000045, 7.271310948000064 53.701237578000075, 7.550173 53.67503749900004, 7.809895500000039 53.70766199900004, 7.996700715000031 53.70301416500007)), ((6.930503093000027 53.684513311000046, 6.903872651000029 53.58823138200006, 6.840839148000043 53.62335561700007, 6.809191596000062 53.67931934200004, 6.848968290000073 53.699006060000045, 6.930503093000027 53.684513311000046)), ((6.751453668000067 53.63516844000003, 6.790050961000077 53.543680632000076, 6.657427111000061 53.55872785300005, 6.63848002900005 53.59210563200003, 6.751453668000067 53.63516844000003))) │
# │ FRK1    │         2 │ FR        │ Auvergne                   │ Auvergne                   │        0.0 │         0 │          0 │ FR           │ FRK        │ FRK1       │ POLYGON ((3.23194509700005 46.69354545900006, 3.515243024000029 46.68640084100008, 3.629422500000032 46.749456499000075, 3.645437451000021 46.70075297200003, 3.721536231000073 46.62529408600005, 3.742786737000074 46.54906916200008, 3.991444086000058 46.46425519500008, 3.985708614000032 46.328153014000065, 3.899538500000062 46.275907999000026, 3.80737232000007 46.23120152900003, 3.806403572000022 46.00003821100006, 3.694015 45.930727999000055, 3.718651358000045 45.77657523200003, 3.968680147000043 45.51449160300007, 3.89740850000004 45.357079999000064, 4.268552139000064 45.37859660700008, 4.483132 45.23644549900007, 4.270905961000039 44.98104996500007, 3.862531 44.743865999000036, 3.734431011000027 44.82520903500006, 3.479491154000073 44.843169241000055, 3.361347500000022 44.971407999000064, 3.106397142000048 44.86230932600006, 2.981675500000051 44.64467299900008, 2.86029677700003 44.854160782000065, 2.72751239300004 44.921746057000064, 2.493189854000036 44.66891509000004, 2.296069105000072 44.63208314900004, 2.207473 44.61552899900005, 2.062908 44.97650449900004, 2.22855437000004 45.248610797000026, 2.296069105000072 45.28911917800008, 2.478181372000051 45.39838529600007, 2.50812746400004 45.48016668200006, 2.492129500000033 45.73766999900005, 2.433643786000061 45.815798373000064, 2.594965958000046 45.981133631000034, 2.565372500000024 46.14303599900006, 2.281043500000067 46.42040349900003, 2.570033697000042 46.55381052400003, 2.687630779000074 46.710648958000036, 3.032063 46.79490949900003, 3.23194509700005 46.69354545900006))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │
# │ FRL0    │         2 │ FR        │ Provence-Alpes-Côte d’Azur │ Provence-Alpes-Côte d’Azur │        0.0 │         0 │          0 │ FR           │ FRL        │ FRL0       │ POLYGON ((6.26057 45.12684399900007, 6.432313515000033 45.06386110600005, 6.630051 45.109856499000045, 6.779271202000075 44.896757164000064, 7.008916138000075 44.83098541600003, 7.065755 44.713464499000054, 6.948443 44.654741999000066, 6.874576976000071 44.52313876100004, 6.887428 44.36128699900007, 7.036656494000056 44.23342831400004, 7.384291562000044 44.12332477500007, 7.602905948000057 44.142539776000035, 7.714236500000027 44.06151349900006, 7.522078972000031 43.88938936300008, 7.529827 43.78400799900004, 7.439249 43.74901949900004, 7.437358 43.75163249900004, 7.413383 43.73457699900007, 7.412828 43.731712499000025, 7.410282962000053 43.72934965800005, 7.415697 43.725910499000065, 7.171281675000046 43.64404582700007, 6.97736992800003 43.51168672500006, 6.931325500000071 43.48025799900006, 6.900392534000048 43.44171460900003, 6.72264283800007 43.38479552200005, 6.637626241000021 43.177328842000065, 6.29353003500006 43.10802554400004, 5.831116217000044 43.06291480200008, 5.671879500000045 43.179268999000044, 5.399941026000022 43.212265358000025, 5.303586857000028 43.33174108400004, 5.070576313000061 43.33822733300008, 4.89313114600003 43.42130097800003, 4.667335408000042 43.36424636100003, 4.527869184000053 43.44120806800004, 4.230280500000049 43.46018349900004, 4.290254207000032 43.51168672500006, 4.49058138700002 43.68372037900008, 4.614663882000059 43.70103928900005, 4.739059500000053 43.92406199900006, 4.797846238000034 44.02122832900005, 4.649227500000052 44.27035999900005, 4.650611 44.32980299900004, 4.875948612000059 44.246226920000026, 4.89877782700006 44.36498013100004, 4.983976957000039 44.41037741300005, 5.039873048000061 44.309806268000045, 5.498786500000051 44.11571649900003, 5.681106032000059 44.18990299600006, 5.636853132000056 44.30084321900006, 5.459264184000062 44.36554730700004, 5.451808709000034 44.44699912300007, 5.606143234000058 44.48592734700003, 5.639170892000038 44.62777151900008, 5.80147 44.706777499000054, 6.007271475000039 44.82202343300003, 6.325838126000065 44.88487689500005, 6.327697046000026 44.956881698000075, 6.23878508100006 45.04196770600004, 6.26057 45.12684399900007))                        │
# │ TR61    │         2 │ TR        │ Antalya, Isparta, Burdur   │ Antalya, Isparta, Burdur   │        0.0 │         0 │          0 │ TR           │ TR6        │ TR61       │ POLYGON ((31.300975 37.404258999000035, 31.49958651000003 37.32772765900006, 31.761584893000077 37.33270353100005, 31.977425667000034 37.10046822000004, 32.457231500000034 36.73847099900007, 32.51992733800006 36.52923957200005, 32.516082691000065 36.41421372600007, 32.573227 36.357623999000054, 32.57634 36.093232999000065, 32.33021381100008 36.210706713000036, 32.043583485000056 36.52923957200005, 31.277582782000025 36.816344435000076, 30.661596548000034 36.87353331500003, 30.577369910000073 36.77133339200003, 30.550263357000063 36.52923957200005, 30.44589990700007 36.259190268000054, 30.208189193000067 36.308715042000074, 29.76409060700007 36.13833110300004, 29.26056150000005 36.30439899900006, 29.326552495000044 36.43077918300003, 29.487043836000055 36.52923957200005, 29.642303135000077 36.692041181000036, 29.73071045300003 36.88157660100006, 29.713264500000037 36.95630949900004, 29.416882267000062 36.880173746000025, 29.341447 37.006848999000056, 29.585441983000067 37.37586158200003, 29.512705211000025 37.598529933000066, 29.852119 37.75228549900004, 30.039979500000072 37.752413999000055, 30.17202761200008 37.95025530200007, 30.45415961100008 38.16253879100003, 30.661596548000034 38.24303478600007, 31.012107790000073 38.46420758800008, 31.12637837400007 38.478169593000075, 31.23334950000003 38.40997299900005, 31.311428026000044 38.28207176800004, 31.574024130000055 38.07669072700003, 31.43445355500006 37.957526862000066, 31.444393296000044 37.75447743600006, 31.344575458000065 37.635416838000026, 31.300975 37.404258999000035))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      │
# │ ES63    │         2 │ ES        │ Ciudad de Ceuta            │ Ciudad de Ceuta            │        0.0 │         0 │          0 │ ES           │ ES6        │ ES63       │ POLYGON ((-5.339367492999941 35.876148398000055, -5.34337063199996 35.87087626600004, -5.38193549999994 35.913023499000076, -5.377675090999958 35.915968974000066, -5.364974637999978 35.91667742800007, -5.348897416999932 35.90782137900004, -5.340897040999948 35.899756472000036, -5.337821590999965 35.89560658700003, -5.336049750999962 35.890785282000024, -5.335717595999938 35.88565945900007, -5.336852384999929 35.88064980300004, -5.339367492999941 35.876148398000055))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# │ RO11    │         2 │ RO        │ Nord-Vest                  │ Nord-Vest                  │        0.0 │         0 │          0 │ RO           │ RO1        │ RO11       │ POLYGON ((23.193141342000047 48.10954608700007, 23.493605 47.96781149900005, 23.569540919000076 48.00715265900004, 24.215330666000057 47.90290394900006, 24.56784286900006 47.955976451000026, 24.947100500000033 47.72912399900008, 25.02210869000004 47.66731240200005, 24.960837500000025 47.596850999000026, 25.075296552000054 47.51239990400006, 25.063383 47.13653849900004, 24.860746979000055 47.08754303900008, 24.709029608000037 46.92625561700004, 24.571143106000022 46.921035747000076, 24.40102433800007 46.76217447500005, 24.179575500000055 46.804696499000045, 24.089070563000064 46.737823330000026, 23.985275 46.43091799900003, 23.623410153000066 46.43273092600003, 23.388519969000072 46.530138297000065, 23.062094456000068 46.481750470000065, 22.811950500000023 46.56885949900004, 22.689849007000078 46.51272268500003, 22.67657550000007 46.40582549900006, 22.429523863000043 46.400250877000076, 22.05608989700005 46.63998312700005, 21.441398 46.651466999000036, 21.658955 47.02213149900007, 22.01472075600003 47.39794173300004, 22.041073100000062 47.52208987300003, 22.12832 47.598089499000025, 22.180837500000052 47.60009449900008, 22.22183771500005 47.66731240200005, 22.466854351000052 47.78862331000005, 22.667929489000073 47.79513943100005, 22.89627050000007 47.954120499000055, 23.193141342000047 48.10954608700007))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           │
# │ RS11    │         2 │ RS        │ City of Belgrade           │ Београдски регион          │        0.0 │         0 │          0 │ RS           │ RS1        │ RS11       │ POLYGON ((20.819537 44.65787299900006, 20.768387277000045 44.55449452500005, 20.824775265000028 44.47083192100007, 20.763458566000054 44.40954066200004, 20.783538 44.32662399900005, 20.485804346000066 44.42995954000003, 20.400346 44.31311849900004, 20.25867803600005 44.30264432300004, 20.204643186000055 44.505578220000075, 19.990309500000023 44.58564749900006, 19.98584950000003 44.642280999000036, 20.104377288000023 44.723232239000026, 20.334135 45.07440999900007, 20.414361 45.084167999000044, 20.614807755000072 44.88632295000008, 20.663588547000074 44.735294786000054, 20.819537 44.65787299900006))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            │
# │ NL23    │         2 │ NL        │ Flevoland                  │ Flevoland                  │        0.0 │         0 │          0 │ NL           │ NL2        │ NL23       │ POLYGON ((5.864311 52.51816949900007, 5.768641994000063 52.41596633100005, 5.404633 52.249629999000035, 5.335462 52.29021849900005, 5.079161 52.388652999000044, 5.163083405000066 52.43140012600003, 5.060426500000062 52.57893749900006, 5.349825157000055 52.69285598400006, 5.377261500000031 52.764804999000035, 5.795148500000039 52.80649949900004, 5.96837677000002 52.666753423000046, 5.845522980000055 52.59795871500006, 5.864311 52.51816949900007))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │
# └─────────┴───────────┴───────────┴────────────────────────────┴────────────────────────────┴────────────┴───────────┴────────────┴──────────────┴────────────┴────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#   10 rows                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  12 columns

# %% [markdown]
# Let's build a separate entity, mapping every Kreis and Bundesland to the NUTS-1,2,3 identifiers. We can use the kreis_crops view immediately. We'll augment it with the nuts2,3 ids, and then augment it by joining with the NUTS-id-enriched table.

# %%
# SEE https://duckdb.org/docs/stable/sql/meta/information_schema
con.execute("""
    select column_name
    from information_schema.columns
    where table_schema='main'
      and table_name = 'vw_kreise_crops_with_nuts1'
    order by ordinal_position
""").fetchall()
# Out:
# [('year',),
#  ('kreis_code',),
#  ('kreis_name',),
#  ('crop_name',),
#  ('yield_dt_ha_dec',),
#  ('bundesland_code',),
#  ('nuts1',),
#  ('is_country',),
#  ('is_bundesland',),
#  ('is_region',),
#  ('is_kreis',),
#  ('is_kreis_8',),
#  ('is_unexpected_kreis_code',)]

# %%
con.sql("""
    -- New transitory view
    create or replace view vw__mapping__nuts1_to_kreise as
    select distinct kreis_code, kreis_name, nuts1, is_country, is_bundesland, is_region, is_kreis, is_kreis_8, is_unexpected_kreis_code
    from vw_kreise_crops_with_nuts1
    order by kreis_code;
    -- Sample 10 rows
    select * from vw__mapping__nuts1_to_kreise
    using sample 10 rows;
""")
# Out:
# ┌────────────┬───────────────────────────────────────────┬─────────┬────────────┬───────────────┬───────────┬──────────┬────────────┬──────────────────────────┐
# │ kreis_code │                kreis_name                 │  nuts1  │ is_country │ is_bundesland │ is_region │ is_kreis │ is_kreis_8 │ is_unexpected_kreis_code │
# │  varchar   │                  varchar                  │ varchar │  boolean   │    boolean    │  boolean  │ boolean  │  boolean   │         boolean          │
# ├────────────┼───────────────────────────────────────────┼─────────┼────────────┼───────────────┼───────────┼──────────┼────────────┼──────────────────────────┤
# │ 12060      │ Barnim, Landkreis                         │ DE4     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 09273      │ Kelheim, Landkreis                        │ DE2     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 05114      │ Krefeld, kreisfreie Stadt                 │ DEA     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 14626      │ Görlitz, Landkreis                        │ DED     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 06611      │ Kassel, kreisfreie Stadt, documenta-Stadt │ DE7     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 14375      │ Döbeln, Landkreis                         │ DED     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 14272      │ Bautzen, Landkreis                        │ DED     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 03353      │ Harburg, Landkreis                        │ DE9     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 05570      │ Warendorf, Kreis                          │ DEA     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 05124      │ Wuppertal, kreisfreie Stadt               │ DEA     │ false      │ false         │ false     │ true     │ false      │ false                    │
# └────────────┴───────────────────────────────────────────┴─────────┴────────────┴───────────────┴───────────┴──────────┴────────────┴──────────────────────────┘
#   10 rows                                                                                                                                            9 columns

# %% [markdown]
# The `kreis_name`s contain extra qualifiers like "kreisefreie Stadt", "Landkreis" and more.
# To enhance matching, we'll need to split off the qualifier from the names proper. As a reminder, on the Kreis-level,
#
# - 2 digits: country `DG` at NUTS-0 or Bundesland at NUTS-1 -> either is_country = true or is_bundesland = true
# - 3 digits: NUTS-2 -> is_region = true
# - 5 digits: NUTS-3 -> is_kreis = true
# - 8 digits: NUTS-3 -> is_kreis_8 = true
# - other: unknown -> is_unexpected_kreis_code = true
#
# In fact, we can normalize further, by augmenting nuts-1, nuts-2, nuts-3 as three new, separate tables with the Kreis identifiers. But the data set is small, performance wise it's fine to keep it denormalized during EDA.

# %%
con.sql("""
    select * from nuts1 n
    where n.cntr_code = 'DE'
      and n.nuts_name like 'Schleswig%'
""")
# Out:
# ┌─────────┬───────────┬───────────┬────────────────────┬────────────────────┬────────────┬───────────┬────────────┬──────────────┬────────────┬────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ NUTS_ID │ LEVL_CODE │ CNTR_CODE │     NAME_LATN      │     NUTS_NAME      │ MOUNT_TYPE │ URBN_TYPE │ COAST_TYPE │ country_code │ nuts1_code │ nuts2_code │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          geometry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │
# │ varchar │   int32   │  varchar  │      varchar       │      varchar       │   int32    │   int32   │   int32    │   varchar    │  varchar   │  varchar   │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          geometry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │
# ├─────────┼───────────┼───────────┼────────────────────┼────────────────────┼────────────┼───────────┼────────────┼──────────────┼────────────┼────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ DEF     │         1 │ DE        │ Schleswig-Holstein │ Schleswig-Holstein │          0 │         0 │          0 │ DE           │ DEF        │ NULL       │ MULTIPOLYGON (((11.272382089000075 54.41470657800005, 11.12805181400006 54.41077233400006, 11.027967267000065 54.45021477800003, 11.026139068000077 54.507596489000036, 11.06072791500003 54.52990118100007, 11.210658012000067 54.507596489000036, 11.272382089000075 54.41470657800005)), ((9.113097 54.873601499000074, 9.294053628000029 54.81052229800008, 9.420151500000031 54.83195649900006, 9.422934 54.82322299900005, 9.491949500000032 54.82263549900006, 9.92596868000004 54.77731669100007, 10.03117 54.63657499900006, 9.970446755000069 54.50674986900003, 10.168517 54.432844999000054, 10.174373837000076 54.34629987400007, 10.341463898000029 54.42795049300008, 10.71375050000006 54.30507249900006, 10.937591767000072 54.37253642600007, 11.073009282000044 54.31540099100005, 11.066790742000023 54.19220768500003, 10.781582736000075 54.06589680500008, 10.840886 53.99189399900007, 10.903661500000055 53.956821999000056, 10.762964500000066 53.81115299900006, 10.782266690000029 53.74212887200008, 10.951918500000033 53.64762249900008, 10.595047 53.363927499000056, 10.469184 53.38584399900003, 10.307954 53.433200999000064, 10.236678500000039 53.49635449900006, 10.17859326100006 53.534967341000026, 10.168447086000072 53.681768281000075, 10.072805 53.70963399900006, 9.945376 53.65292799900004, 9.730104 53.55758099900004, 9.48589 53.70766449900003, 9.272733 53.86766249900006, 9.199751 53.880104499000026, 9.028210259000048 53.88013263800008, 8.832592 54.023929499000076, 8.955681569000035 54.07128012900006, 8.828785045000075 54.164988366000046, 8.844804500000066 54.26632849900005, 8.69326122900003 54.32595365100008, 8.878017963000048 54.43896662100008, 8.855166754000038 54.56355163100005, 8.65460243900003 54.81183706000007, 8.635926 54.91168299900005, 9.028210259000048 54.88064693900003, 9.113097 54.873601499000074)), ((8.704124470000068 54.55643013700006, 8.68307683300003 54.47645184000004, 8.554701859000033 54.50188727500006, 8.555420193000032 54.53786589600003, 8.704124470000068 54.55643013700006)), ((8.574208988000066 54.677202298000054, 8.485066035000045 54.67675076200004, 8.38523510400006 54.71494280600007, 8.430900606000023 54.751397679000036, 8.596975197000063 54.743567161000044, 8.574208988000066 54.677202298000054)), ((8.383420461000071 54.64726116000003, 8.333663314000034 54.60706518400008, 8.263748090000036 54.66749105100007, 8.358313922000036 54.73776141600007, 8.383420461000071 54.64726116000003)), ((8.375451834000046 54.86717631300007, 8.271810261000041 54.865587582000046, 8.330537957000047 54.98211315800006, 8.375710689000073 54.95904243400008, 8.375451834000046 54.86717631300007)), ((7.940571306000038 54.20554988100008, 7.916555794000033 54.119422787000076, 7.800921521000021 54.21118334100004, 7.888383327000042 54.23612984400006, 7.940571306000038 54.20554988100008))) │
# └─────────┴───────────┴───────────┴────────────────────┴────────────────────┴────────────┴───────────┴────────────┴──────────────┴────────────┴────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# SEE https://duckdb.org/docs/stable/sql/functions/text#substringstring-start-length
con.sql("""
    with mapped as (
        select distinct columns(* exclude(year, crop_name, yield_dt_ha_dec))
            , n2.nuts_id nuts2_id, n2.name_latn nuts2_name_latin, n2.nuts_name nuts2_name
        from vw_kreise_crops_with_nuts1 kcn1
        left join nuts2 n2 on kcn1.is_region
                        and starts_with(n2.nuts_id, kcn1.nuts1) -- higher-level NUTS id prefix match
                        -- TODO: Might need to strip off comma-separated suffix qualifiers
                        and (contains(lower(n2.nuts_name), lower(kcn1.kreis_name)) or contains(lower(kcn1.kreis_name), lower(n2.nuts_name)))
                    -- and (lower(v.bundesland_name) like '%' || lower(n.nuts_name) || '%'
                    --      or lower(n.nuts_name) like '%' || lower(v.bundesland_name) || '%')
    )
    -- TODO: define as a view or table - mappping__nuts2_to_kreise
    -- , unmapped as (select kreis_code, kreis_name,
    select * from mapped
    where is_region
      and nuts2_id is null
""")
# Out:
# ┌────────────┬────────────────────────────────┬─────────────────┬─────────┬────────────┬───────────────┬───────────┬──────────┬────────────┬──────────────────────────┬─────────┬───────────┬───────────┬───────────┬───────────┬────────────┬───────────┬────────────┬──────────────┬────────────┬────────────┬──────────┬──────────┬──────────────────┬────────────┐
# │ kreis_code │           kreis_name           │ bundesland_code │  nuts1  │ is_country │ is_bundesland │ is_region │ is_kreis │ is_kreis_8 │ is_unexpected_kreis_code │ NUTS_ID │ LEVL_CODE │ CNTR_CODE │ NAME_LATN │ NUTS_NAME │ MOUNT_TYPE │ URBN_TYPE │ COAST_TYPE │ country_code │ nuts1_code │ nuts2_code │ geometry │ nuts2_id │ nuts2_name_latin │ nuts2_name │
# │  varchar   │            varchar             │     varchar     │ varchar │  boolean   │    boolean    │  boolean  │ boolean  │  boolean   │         boolean          │ varchar │   int32   │  varchar  │  varchar  │  varchar  │   double   │   int32   │   int32    │   varchar    │  varchar   │  varchar   │ geometry │ varchar  │     varchar      │  varchar   │
# ├────────────┼────────────────────────────────┼─────────────────┼─────────┼────────────┼───────────────┼───────────┼──────────┼────────────┼──────────────────────────┼─────────┼───────────┼───────────┼───────────┼───────────┼────────────┼───────────┼────────────┼──────────────┼────────────┼────────────┼──────────┼──────────┼──────────────────┼────────────┤
# │ 151        │ Dessau, Statistische Region    │ 15              │ DEE     │ false      │ false         │ true      │ false    │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 152        │ Halle, Statistische Region     │ 15              │ DEE     │ false      │ false         │ true      │ false    │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 153        │ Magdeburg, Statistische Region │ 15              │ DEE     │ false      │ false         │ true      │ false    │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# └────────────┴────────────────────────────────┴─────────────────┴─────────┴────────────┴───────────────┴───────────┴──────────┴────────────┴──────────────────────────┴─────────┴───────────┴───────────┴───────────┴───────────┴────────────┴───────────┴────────────┴──────────────┴────────────┴────────────┴──────────┴──────────┴──────────────────┴────────────┘

# %% [markdown]
# So we couldn't map Dessau, Halle, and Magdeburg that way... Let's see if the nuts2 dataset contains them at all...

# %%
con.sql("""
    select * from nuts2 n
    where n.cntr_code = 'DE'
      and (lower(n.nuts_name) like '%dessau%' or lower(n.nuts_name) like '%halle%' or lower(n.nuts_name) like '%magdeburg%'
        or lower(n.name_latn) like '%dessau%' or lower(n.name_latn) like '%halle%' or lower(n.name_latn) like '%magdeburg%'
      )
""")
# Out:
# ┌─────────┬───────────┬───────────┬───────────┬───────────┬────────────┬───────────┬────────────┬──────────────┬────────────┬────────────┬──────────┐
# │ NUTS_ID │ LEVL_CODE │ CNTR_CODE │ NAME_LATN │ NUTS_NAME │ MOUNT_TYPE │ URBN_TYPE │ COAST_TYPE │ country_code │ nuts1_code │ nuts2_code │ geometry │
# │ varchar │   int32   │  varchar  │  varchar  │  varchar  │   double   │   int32   │   int32    │   varchar    │  varchar   │  varchar   │ geometry │
# └─────────┴───────────┴───────────┴───────────┴───────────┴────────────┴───────────┴────────────┴──────────────┴────────────┴────────────┴──────────┘
#                                                                        0 rows

# %% [markdown]
# No, Dessau, Halle, and Magdeburg are not defined at NUTS-2, maybe at NUTS-3?

# %%
con.sql("""
    select * from nuts3 n
    where n.cntr_code = 'DE'
      and (lower(n.nuts_name) like '%dessau%' or lower(n.nuts_name) like '%halle%' or lower(n.nuts_name) like '%magdeburg%'
        or lower(n.name_latn) like '%dessau%' or lower(n.name_latn) like '%halle%' or lower(n.name_latn) like '%magdeburg%'
      )
""")
# Out:
# ┌─────────┬───────────┬───────────┬─────────────────────────────────┬─────────────────────────────────┬────────────┬───────────┬────────────┬──────────────┬────────────┬────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ NUTS_ID │ LEVL_CODE │ CNTR_CODE │            NAME_LATN            │            NUTS_NAME            │ MOUNT_TYPE │ URBN_TYPE │ COAST_TYPE │ country_code │ nuts1_code │ nuts2_code │                                                                                                                  geometry                                                                                                                   │
# │ varchar │   int32   │  varchar  │             varchar             │             varchar             │   int32    │   int32   │   int32    │   varchar    │  varchar   │  varchar   │                                                                                                                  geometry                                                                                                                   │
# ├─────────┼───────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼───────────┼────────────┼──────────────┼────────────┼────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ DEE01   │         3 │ DE        │ Dessau-Roßlau, Kreisfreie Stadt │ Dessau-Roßlau, Kreisfreie Stadt │          4 │         2 │          3 │ DE           │ DEE        │ DEE0       │ POLYGON ((12.335906500000021 51.73381399900006, 12.130649538000057 51.812426783000035, 12.151418911000064 51.88963360500003, 12.281266500000072 51.97029249900004, 12.335906500000021 51.73381399900006))                                   │
# │ DEE02   │         3 │ DE        │ Halle (Saale), Kreisfreie Stadt │ Halle (Saale), Kreisfreie Stadt │          4 │         2 │          3 │ DE           │ DEE        │ DEE0       │ POLYGON ((11.85473154300007 51.51535991000003, 12.017493674000036 51.54244010600007, 12.057736567000063 51.48362494700007, 12.011401290000038 51.41118878300006, 11.95233629200004 51.40566903400003, 11.85473154300007 51.51535991000003)) │
# │ DEE03   │         3 │ DE        │ Magdeburg, Kreisfreie Stadt     │ Magdeburg, Kreisfreie Stadt     │          4 │         2 │          3 │ DE           │ DEE        │ DEE0       │ POLYGON ((11.704552 52.19947099900003, 11.748724500000037 52.09320149900003, 11.637069 52.030117999000026, 11.540659381000069 52.110173598000074, 11.647484904000066 52.21359282200007, 11.704552 52.19947099900003))                       │
# └─────────┴───────────┴───────────┴─────────────────────────────────┴─────────────────────────────────┴────────────┴───────────┴────────────┴──────────────┴────────────┴────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Yes! So we've discovered a **discrepancy between NUTS-2 vs NUTS-3 and the Kreis-level definitions at Regionalstatistik.de** - even though these three cities have 3-digit Regionalstatistik nomenclature, they live not at NUTS-2 as regions, but at NUTS-3 level of granularity. We take a note here for them, and will map them individually in the next step to a NUTS-3 identifier. This should be kept in mind when working with the data.

# %% [markdown]
# #### Kreise -> NUTS-3
#
# This is a bit more challenging to express, because we need to accurately join
#
# 1. on the Kreise codes with the NUTS-2 codes for Dessau, Halle, and Magdeburg, and
# 2. on the Kreise codes with the NUTS-3 codes for all 5-digit and 8-digit Kreise codes.

# %%
con.sql("""
    with mapped as (
        -- Again, just reusing the existing small data set instead of redefining, now in this 1st EDA iteration, we'll clean up when done:
        select distinct columns(* exclude(year, crop_name, yield_dt_ha_dec))
             , n3.nuts_id nuts3_id, n3.name_latn nuts3_name_latin, n3.nuts_name nuts3_name
        from vw_kreise_crops_with_nuts1 kcn1
        -- First, the most obvious part - the NUTS-3 join:
        left join nuts3 n3 on (kcn1.is_kreis or kcn1.is_kreis_8)
                        and starts_with(n3.nuts_id, kcn1.nuts1) -- higher-higher-level NUTS id prefix match (TODO: do this on NUTS-2 basis)
                        -- TODO: Might need to strip off comma-separated suffix qualifiers
                        and (contains(lower(n3.nuts_name), lower(kcn1.kreis_name)) or contains(lower(kcn1.kreis_name), lower(n3.nuts_name)))
                    -- and (lower(v.bundesland_name) like '%' || lower(n.nuts_name) || '%'
                    --      or lower(n.nuts_name) like '%' || lower(v.bundesland_name) || '%')
    )
    -- , unmapped as (select kreis_code, kreis_name,
    select * from mapped
    where (is_kreis or is_kreis_8)
      and nuts3_id is null
""")
# Out:
# ┌────────────┬──────────────────────────────────────────┬─────────────────┬─────────┬────────────┬───────────────┬───────────┬──────────┬────────────┬──────────────────────────┬─────────┬───────────┬───────────┬───────────┬───────────┬────────────┬───────────┬────────────┬──────────────┬────────────┬────────────┬──────────┬──────────┬──────────────────┬────────────┐
# │ kreis_code │                kreis_name                │ bundesland_code │  nuts1  │ is_country │ is_bundesland │ is_region │ is_kreis │ is_kreis_8 │ is_unexpected_kreis_code │ NUTS_ID │ LEVL_CODE │ CNTR_CODE │ NAME_LATN │ NUTS_NAME │ MOUNT_TYPE │ URBN_TYPE │ COAST_TYPE │ country_code │ nuts1_code │ nuts2_code │ geometry │ nuts3_id │ nuts3_name_latin │ nuts3_name │
# │  varchar   │                 varchar                  │     varchar     │ varchar │  boolean   │    boolean    │  boolean  │ boolean  │  boolean   │         boolean          │ varchar │   int32   │  varchar  │  varchar  │  varchar  │   int32    │   int32   │   int32    │   varchar    │  varchar   │  varchar   │ geometry │ varchar  │     varchar      │  varchar   │
# ├────────────┼──────────────────────────────────────────┼─────────────────┼─────────┼────────────┼───────────────┼───────────┼──────────┼────────────┼──────────────────────────┼─────────┼───────────┼───────────┼───────────┼───────────┼────────────┼───────────┼────────────┼──────────────┼────────────┼────────────┼──────────┼──────────┼──────────────────┼────────────┤
# │ 04011      │ Bremen, kreisfreie Stadt                 │ NULL            │ NULL    │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 05334002   │ Aachen, kreisfreie Stadt                 │ 05              │ DEA     │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11001001   │ Berlin-Mitte                             │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11004004   │ Berlin-Charlottenburg-Wilmersdorf        │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11007007   │ Berlin-Tempelhof-Schöneberg              │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 14171      │ Annaberg, Landkreis                      │ 14              │ DED     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 14177      │ Freiberg, Landkreis                      │ 14              │ DED     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 15268      │ Weißenfels, Kreis                        │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 15367      │ Schönebeck, Kreis                        │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 09373      │ Neumarkt i.d.OPf., Landkreis             │ 09              │ DE2     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │   ·        │         ·                                │ ·               │  ·      │   ·        │   ·           │   ·       │  ·       │   ·        │   ·                      │  ·      │        ·  │  ·        │  ·        │  ·        │         ·  │        ·  │         ·  │  ·           │  ·         │  ·         │  ·       │  ·       │  ·               │  ·         │
# │   ·        │         ·                                │ ·               │  ·      │   ·        │   ·           │   ·       │  ·       │   ·        │   ·                      │  ·      │        ·  │  ·        │  ·        │  ·        │         ·  │        ·  │         ·  │  ·           │  ·         │  ·         │  ·       │  ·       │  ·               │  ·         │
# │   ·        │         ·                                │ ·               │  ·      │   ·        │   ·           │   ·       │  ·       │   ·        │   ·                      │  ·      │        ·  │  ·        │  ·        │  ·        │         ·  │        ·  │         ·  │  ·           │  ·         │  ·         │  ·       │  ·       │  ·               │  ·         │
# │ 15369      │ Wernigerode, Kreis                       │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 03156      │ Osterode am Harz, Landkreis              │ 03              │ DE9     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 09374      │ Neustadt a.d.Waldnaab, Landkreis         │ 09              │ DE2     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11006006   │ Berlin-Steglitz-Zehlendorf               │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11009009   │ Berlin-Treptow-Köpenick                  │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 13005      │ Stralsund, Hansestadt,  kreisfreie Stadt │ 13              │ DE8     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 13053      │ Güstrow, Landkreis                       │ 13              │ DE8     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 15151      │ Anhalt-Zerbst, Kreis                     │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 15265      │ Saalkreis                                │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 15357      │ Halberstadt, Kreis                       │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# └────────────┴──────────────────────────────────────────┴─────────────────┴─────────┴────────────┴───────────────┴───────────┴──────────┴────────────┴──────────────────────────┴─────────┴───────────┴───────────┴───────────┴───────────┴────────────┴───────────┴────────────┴──────────────┴────────────┴────────────┴──────────┴──────────┴──────────────────┴────────────┘
#   78 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                25 columns

# %% [markdown]
# So 78 mismatched 5-digit or 8-digit Kreise. Our **goal** is to ensure consistency and not lose any important entities.

# %% [markdown]
# ##### Investigate Mismatches
#
# Let's investigate before we tweak the join expression. Berlin's Bezirke is a few of them, which is clear. Note that we mapped `nuts1` earlier to lower-level entities, but now set them values to null instead.
#
# - [ ] TODO: Set either all nuts levels to null that are at different levels of granularity for a Kreise code, or, by contrast, set them to the parent code to establish the easy lookup for nested tree relationships.
#
# Note that I'm using star expressions for simplicit here, as the data sets are tiny. With larger or wider data sets, specifying columns is key.
#
# Let's first check whether we can simplify the lookup queries (for the German Kreise) if we may assume that `nuts.name_latn` always agrees with `nuts.nuts_name`.

# %%
con.sql("""
    select nuts_id, levl_code, cntr_code, name_latn, nuts_name
    from nuts3 n
    where name_latn <> nuts_name
      and cntr_code = 'DE'  -- we are interested here only in the German entities for the Kreise
    order by nuts_id
""")
# Out:
# ┌─────────┬───────────┬───────────┬───────────┬───────────┐
# │ NUTS_ID │ LEVL_CODE │ CNTR_CODE │ NAME_LATN │ NUTS_NAME │
# │ varchar │   int32   │  varchar  │  varchar  │  varchar  │
# └─────────┴───────────┴───────────┴───────────┴───────────┘
#                           0 rows

# %% [markdown]
# Yes, indeed, for Germany they all agree. This halves our filter condition count.

# %%
con.sql("""
    select *
    from nuts3 n
    where n.cntr_code = 'DE'
      and (lower(n.nuts_name) like '%bremen%' or lower(n.nuts_name) like '%berlin%' or lower(n.nuts_name) like '%freiberg%')
""")
# Out:
# ┌─────────┬───────────┬───────────┬──────────────────────────┬──────────────────────────┬────────────┬───────────┬────────────┬──────────────┬────────────┬────────────┬───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ NUTS_ID │ LEVL_CODE │ CNTR_CODE │        NAME_LATN         │        NUTS_NAME         │ MOUNT_TYPE │ URBN_TYPE │ COAST_TYPE │ country_code │ nuts1_code │ nuts2_code │                                                                                                                                                                                                       geometry                                                                                                                                                                                                        │
# │ varchar │   int32   │  varchar  │         varchar          │         varchar          │   int32    │   int32   │   int32    │   varchar    │  varchar   │  varchar   │                                                                                                                                                                                                       geometry                                                                                                                                                                                                        │
# ├─────────┼───────────┼───────────┼──────────────────────────┼──────────────────────────┼────────────┼───────────┼────────────┼──────────────┼────────────┼────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ DE300   │         3 │ DE        │ Berlin                   │ Berlin                   │          4 │         1 │          3 │ DE           │ DE3        │ DE30       │ POLYGON ((13.610827500000028 52.54423549900008, 13.66698 52.47416699900003, 13.723263691000056 52.43658333500008, 13.699738 52.377882999000065, 13.420985 52.376246999000045, 13.311926 52.399185499000055, 13.165898 52.39427549900006, 13.109412838000026 52.428361109000036, 13.13900626000003 52.50205882300003, 13.164263 52.59890049900008, 13.39854 52.648194499000056, 13.610827500000028 52.54423549900008)) │
# │ DE501   │         3 │ DE        │ Bremen, Kreisfreie Stadt │ Bremen, Kreisfreie Stadt │          4 │         1 │          1 │ DE           │ DE5        │ DE50       │ POLYGON ((8.984185500000024 53.126070999000035, 8.915827 53.01102149900004, 8.711424 53.04462999900005, 8.654898500000058 53.10886449900005, 8.485330500000032 53.22711999900008, 8.58510564900007 53.20144491500008, 8.984185500000024 53.126070999000035))                                                                                                                                                          │
# └─────────┴───────────┴───────────┴──────────────────────────┴──────────────────────────┴────────────┴───────────┴────────────┴──────────────┴────────────┴────────────┴───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Let's focus on Berlin for a moment - Bezirke is one thing, the Bundesland Berlin is another level. Let's discover how Berlin appears in NUTS-1,2,3 and in the Kreise dataset

# %%
# Specifically for Berlin:
con.sql("""
    with berlin_kreise as (
        select distinct k.kreis_code, k.kreis_name
        from vw_kreise_crops_with_nuts1 k
        where contains(lower(k.kreis_name), 'berlin'))
    select n1.nuts_id nuts1_id, n2.nuts_id nuts2_id, n3.nuts_id nuts3_id
         , n1.name_latn nuts1_name, n2.name_latn nuts2_name, n3.name_latn nuts3_name
         -- , k.kreis_code, k.kreis_name
    from nuts1 n1
    full outer join nuts2 n2 on contains(n2.nuts_id, n1.nuts_id)
    full outer join nuts3 n3 on contains(n3.nuts_id, n2.nuts_id)
    -- left join berlin_kreise k
    where n1.cntr_code = 'DE'
      and (n1.nuts_id = 'DE3' or contains(lower(n1.name_latn), 'berlin') or contains(lower(n2.name_latn), 'berlin') or contains(lower(n3.name_latn), 'berlin'))
""")
# Out:
# ┌──────────┬──────────┬──────────┬────────────┬────────────┬────────────┐
# │ nuts1_id │ nuts2_id │ nuts3_id │ nuts1_name │ nuts2_name │ nuts3_name │
# │ varchar  │ varchar  │ varchar  │  varchar   │  varchar   │  varchar   │
# ├──────────┼──────────┼──────────┼────────────┼────────────┼────────────┤
# │ DE3      │ DE30     │ DE300    │ Berlin     │ Berlin     │ Berlin     │
# └──────────┴──────────┴──────────┴────────────┴────────────┴────────────┘

# %%
con.sql("""
    select nuts_id, name_latn, 'nuts1' as nuts_level from nuts1 where contains(lower(name_latn), 'berlin')
    union all
    (select nuts_id, name_latn, 'nuts2' as nuts_level from nuts2 where contains(lower(name_latn), 'berlin'))
    union all
    (select nuts_id, name_latn, 'nuts3' as nuts_level from nuts3 where contains(lower(name_latn), 'berlin'))
""")
# Out:
# ┌─────────┬───────────┬────────────┐
# │ NUTS_ID │ NAME_LATN │ nuts_level │
# │ varchar │  varchar  │  varchar   │
# ├─────────┼───────────┼────────────┤
# │ DE3     │ Berlin    │ nuts1      │
# │ DE30    │ Berlin    │ nuts2      │
# │ DE300   │ Berlin    │ nuts3      │
# └─────────┴───────────┴────────────┘

# %% [markdown]
# So indeed, just that. **NUTS does not distinguish Berlin's Bezirke.**

# %% [markdown]
# Let's now consider the remaining mismatches. Now it's become evident that to avoid mistakes, it's time to define the previous query as a view first.

# %%
# Copy-paste from above, and define a view on top for the `mapped` CTE.
con.sql("""
    create or replace view vw__mapping__kreise_to_nuts3 as
        -- Again, just reusing the existing small data set instead of redefining, now in this 1st EDA iteration, we'll clean up when done:
        select distinct columns(* exclude(year, crop_name, yield_dt_ha_dec))
             , n3.nuts_id nuts3_id, n3.name_latn nuts3_name_latin, n3.nuts_name nuts3_name
        from vw_kreise_crops_with_nuts1 kcn1
        -- First, the most obvious part - the NUTS-3 join:
        left join nuts3 n3 on (kcn1.is_kreis or kcn1.is_kreis_8)
                        and starts_with(n3.nuts_id, kcn1.nuts1) -- higher-higher-level NUTS id prefix match (TODO: do this on NUTS-2 basis)
                        -- TODO: Might need to strip off comma-separated suffix qualifiers
                        and (contains(lower(n3.nuts_name), lower(kcn1.kreis_name)) or contains(lower(kcn1.kreis_name), lower(n3.nuts_name)))
                    -- and (lower(v.bundesland_name) like '%' || lower(n.nuts_name) || '%'
                    --      or lower(n.nuts_name) like '%' || lower(v.bundesland_name) || '%');
    ;
    -- Now another view for the unmapped
    create or replace view vw__mapping__kreise_to_nuts3__failures as
      select * from vw__mapping__kreise_to_nuts3
      where (is_kreis or is_kreis_8)
        and nuts3_id is null
        order by kreis_code;
    -- And now again select the unmapped rows:
    select * from  vw__mapping__kreise_to_nuts3__failures;
""")
# Out:
# ┌────────────┬───────────────────────────────────┬─────────────────┬─────────┬────────────┬───────────────┬───────────┬──────────┬────────────┬──────────────────────────┬─────────┬───────────┬───────────┬───────────┬───────────┬────────────┬───────────┬────────────┬──────────────┬────────────┬────────────┬──────────┬──────────┬──────────────────┬────────────┐
# │ kreis_code │            kreis_name             │ bundesland_code │  nuts1  │ is_country │ is_bundesland │ is_region │ is_kreis │ is_kreis_8 │ is_unexpected_kreis_code │ NUTS_ID │ LEVL_CODE │ CNTR_CODE │ NAME_LATN │ NUTS_NAME │ MOUNT_TYPE │ URBN_TYPE │ COAST_TYPE │ country_code │ nuts1_code │ nuts2_code │ geometry │ nuts3_id │ nuts3_name_latin │ nuts3_name │
# │  varchar   │              varchar              │     varchar     │ varchar │  boolean   │    boolean    │  boolean  │ boolean  │  boolean   │         boolean          │ varchar │   int32   │  varchar  │  varchar  │  varchar  │   int32    │   int32   │   int32    │   varchar    │  varchar   │  varchar   │ geometry │ varchar  │     varchar      │  varchar   │
# ├────────────┼───────────────────────────────────┼─────────────────┼─────────┼────────────┼───────────────┼───────────┼──────────┼────────────┼──────────────────────────┼─────────┼───────────┼───────────┼───────────┼───────────┼────────────┼───────────┼────────────┼──────────────┼────────────┼────────────┼──────────┼──────────┼──────────────────┼────────────┤
# │ 03156      │ Osterode am Harz, Landkreis       │ 03              │ DE9     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 03241001   │ Hannover, Landeshauptstadt        │ 03              │ DE9     │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 03455      │ Friesland, Landkreis              │ 03              │ DE9     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 04011      │ Bremen, kreisfreie Stadt          │ NULL            │ NULL    │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 04012      │ Bremerhaven, kreisfreie Stadt     │ NULL            │ NULL    │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 05334002   │ Aachen, kreisfreie Stadt          │ 05              │ DEA     │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 05354      │ Aachen, Kreis                     │ 05              │ DEA     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 09183      │ Mühldorf a.Inn, Landkreis         │ 09              │ DE2     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 09186      │ Pfaffenhofen a.d.Ilm, Landkreis   │ 09              │ DE2     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 09363      │ Weiden i.d.OPf., kreisfreie Stadt │ 09              │ DE2     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │   ·        │             ·                     │ ·               │  ·      │   ·        │   ·           │   ·       │  ·       │   ·        │   ·                      │  ·      │        ·  │  ·        │  ·        │  ·        │         ·  │        ·  │         ·  │  ·           │  ·         │  ·         │  ·       │  ·       │  ·               │  ·         │
# │   ·        │             ·                     │ ·               │  ·      │   ·        │   ·           │   ·       │  ·       │   ·        │   ·                      │  ·      │        ·  │  ·        │  ·        │  ·        │         ·  │        ·  │         ·  │  ·           │  ·         │  ·         │  ·       │  ·       │  ·               │  ·         │
# │   ·        │             ·                     │ ·               │  ·      │   ·        │   ·           │   ·       │  ·       │   ·        │   ·                      │  ·      │        ·  │  ·        │  ·        │  ·        │         ·  │        ·  │         ·  │  ·           │  ·         │  ·         │  ·       │  ·       │  ·               │  ·         │
# │ 15261      │ Merseburg-Querfurt, Kreis         │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 15265      │ Saalkreis                         │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 15266      │ Sangerhausen, Kreis               │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 15268      │ Weißenfels, Kreis                 │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 15352      │ Aschersleben-Staßfurt, Kreis      │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 15357      │ Halberstadt, Kreis                │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 15362      │ Ohrekreis                         │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 15364      │ Quedlinburg, Kreis                │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 15367      │ Schönebeck, Kreis                 │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 15369      │ Wernigerode, Kreis                │ 15              │ DEE     │ false      │ false         │ false     │ true     │ false      │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# └────────────┴───────────────────────────────────┴─────────────────┴─────────┴────────────┴───────────────┴───────────┴──────────┴────────────┴──────────────────────────┴─────────┴───────────┴───────────┴───────────┴───────────┴────────────┴───────────┴────────────┴──────────────┴────────────┴────────────┴──────────┴──────────┴──────────────────┴────────────┘
#   78 rows (20 shown)                                                                                                                                                                                                                                                                                                                                         25 columns

# %% [markdown]
# So this is Berlin in the Kreise dataset, we need to decide whether we want to fold them into the NUTS-3 Berlin code. Or whether we want to have a 1:1 bijection between Kreise and NUTS codes. **It is not critical for the MVP, though. But must be noted as a limitation.** So we'll briefly peek into the remaining Kreise and move on with that limitation in mind.

# %%
con.sql("""
    select *
    from vw__mapping__kreise_to_nuts3__failures
    where contains(lower(kreis_name), 'berlin')
""")
# Out:
# ┌────────────┬───────────────────────────────────┬─────────────────┬─────────┬────────────┬───────────────┬───────────┬──────────┬────────────┬──────────────────────────┬─────────┬───────────┬───────────┬───────────┬───────────┬────────────┬───────────┬────────────┬──────────────┬────────────┬────────────┬──────────┬──────────┬──────────────────┬────────────┐
# │ kreis_code │            kreis_name             │ bundesland_code │  nuts1  │ is_country │ is_bundesland │ is_region │ is_kreis │ is_kreis_8 │ is_unexpected_kreis_code │ NUTS_ID │ LEVL_CODE │ CNTR_CODE │ NAME_LATN │ NUTS_NAME │ MOUNT_TYPE │ URBN_TYPE │ COAST_TYPE │ country_code │ nuts1_code │ nuts2_code │ geometry │ nuts3_id │ nuts3_name_latin │ nuts3_name │
# │  varchar   │              varchar              │     varchar     │ varchar │  boolean   │    boolean    │  boolean  │ boolean  │  boolean   │         boolean          │ varchar │   int32   │  varchar  │  varchar  │  varchar  │   int32    │   int32   │   int32    │   varchar    │  varchar   │  varchar   │ geometry │ varchar  │     varchar      │  varchar   │
# ├────────────┼───────────────────────────────────┼─────────────────┼─────────┼────────────┼───────────────┼───────────┼──────────┼────────────┼──────────────────────────┼─────────┼───────────┼───────────┼───────────┼───────────┼────────────┼───────────┼────────────┼──────────────┼────────────┼────────────┼──────────┼──────────┼──────────────────┼────────────┤
# │ 11001001   │ Berlin-Mitte                      │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11002002   │ Berlin-Friedrichshain-Kreuzberg   │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11003003   │ Berlin-Pankow                     │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11004004   │ Berlin-Charlottenburg-Wilmersdorf │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11005005   │ Berlin-Spandau                    │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11006006   │ Berlin-Steglitz-Zehlendorf        │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11007007   │ Berlin-Tempelhof-Schöneberg       │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11008008   │ Berlin-Neukölln                   │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11009009   │ Berlin-Treptow-Köpenick           │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11010010   │ Berlin-Marzahn-Hellersdorf        │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11011011   │ Berlin-Lichtenberg                │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# │ 11012012   │ Berlin-Reinickendorf              │ NULL            │ NULL    │ false      │ false         │ false     │ false    │ true       │ false                    │ NULL    │      NULL │ NULL      │ NULL      │ NULL      │       NULL │      NULL │       NULL │ NULL         │ NULL       │ NULL       │ NULL     │ NULL     │ NULL             │ NULL       │
# └────────────┴───────────────────────────────────┴─────────────────┴─────────┴────────────┴───────────────┴───────────┴──────────┴────────────┴──────────────────────────┴─────────┴───────────┴───────────┴───────────┴───────────┴────────────┴───────────┴────────────┴──────────────┴────────────┴────────────┴──────────┴──────────┴──────────────────┴────────────┘
#   12 rows                                                                                                                                                                                                                                                                                                                                                    25 columns

# %% [markdown]
# And these are the remaining 66 Kreise:

# %%
# TODO: refactor to use sql cells, since we've turned to mostly DuckDB in this notebook now; requires removing the connection var (single writer)
# Let's use the jupysql extension with the duckdb-engine
# %load_ext sql
# conn_str =

# %%
# Defining as Pandas df to open in VS Code Data Wrangler; alternative: write to file.
result_df = con.sql("""
    select kreis_code, kreis_name, bundesland_code, nuts1, is_bundesland, is_kreis, is_kreis_8, is_unexpected_kreis_code
    from vw__mapping__kreise_to_nuts3__failures
    where not contains(lower(kreis_name), 'berlin')
""").df()
result_df
# Out:
#    kreis_code                     kreis_name bundesland_code nuts1  \
# 0       03156    Osterode am Harz, Landkreis              03   DE9
# 1    03241001     Hannover, Landeshauptstadt              03   DE9
# 2       03455           Friesland, Landkreis              03   DE9
# 3       04011       Bremen, kreisfreie Stadt             NaN   NaN
# 4       04012  Bremerhaven, kreisfreie Stadt             NaN   NaN
# ..        ...                            ...             ...   ...
# 61      15357             Halberstadt, Kreis              15   DEE
# 62      15362                      Ohrekreis              15   DEE
# 63      15364             Quedlinburg, Kreis              15   DEE
# 64      15367              Schönebeck, Kreis              15   DEE
# 65      15369             Wernigerode, Kreis              15   DEE
#
#     is_bundesland  is_kreis  is_kreis_8  is_unexpected_kreis_code
# 0           False      True       False                     False
# 1           False     False        True                     False
# 2           False      True       False                     False
# 3           False      True       False                     False
# 4           False      True       False                     False
# ..            ...       ...         ...                       ...
# 61          False      True       False                     False
# 62          False      True       False                     False
# 63          False      True       False                     False
# 64          False      True       False                     False
# 65          False      True       False                     False
#
# [66 rows x 8 columns]

# %% [markdown]
# So what the table above is saying, is that there is no NUTS-3 region with a name that either contains or is contained in the `kreis_name`s above. However, at least for Bremen, Bremerhaven, Aachen, and Hannover it should be expected, as they are "large enough". We are assessing our join condition expression - either it's a data gap or our condition is too rigid.
#
# At the same time there's a 5-digit Aachen (Kreis, 05354) and an 8-digit Aachen (kreisfreie Stadt, 05334002). In fact, those are two distinct Kreise. Their identifiers don't match exactly by substring - they share only the prefix `053`. If we strip off the "Kreis"/"kreisfreie Stadt" qualifiers from Aachen, we'll get a duplicate value in the `kreis_name` column.
#
# By now, **we've dived deeper than expected. Let's recap our actual goal - map crop yields to NUTS-3 polygons.** To minimize missing data and have to impute later, it's best to make the mapping accurate and quality-assure (test) its accuracy and completeness. For an MVP, however, trade-offs are necessary, and if we can't adjust our join condition expression to cover 80% of these, we'll record the gap and postpone this reconciliation.

# %% [markdown]
# Let's again try to look up these larger cities - not all of the 66 rows are displayed in the output box above. It is fine.
#
# Let's repeat the lookup as we did for Berlin.

# %%
con.sql("""
    select nuts_id, name_latn, 'nuts1' as nuts_level
    from nuts1
    where contains(lower(name_latn), 'aachen')
       or contains(lower(name_latn), 'hannover')
       or contains(lower(name_latn), 'breme') -- prefix: Bremen/Bremerhaven
    union all
    (select nuts_id, name_latn, 'nuts2' as nuts_level
     from nuts2
     where contains(lower(name_latn), 'aachen')
        or contains(lower(name_latn), 'hannover')
        or contains(lower(name_latn), 'breme'))
    union all
    (select nuts_id, name_latn, 'nuts3' as nuts_level
     from nuts3
     where contains(lower(name_latn), 'aachen')
        or contains(lower(name_latn), 'hannover')
        or contains(lower(name_latn), 'breme'))
""").df()
# Out:
#   NUTS_ID                      NAME_LATN nuts_level
# 0     DE5                         Bremen      nuts1
# 1    DE50                         Bremen      nuts2
# 2    DE92                       Hannover      nuts2
# 3   DEA2D            Städteregion Aachen      nuts3
# 4   DE501       Bremen, Kreisfreie Stadt      nuts3
# 5   DE502  Bremerhaven, Kreisfreie Stadt      nuts3
# 6   DE929                Region Hannover      nuts3

# %% [markdown]
# Ok, now that is a strong hint for the lack of match - none is contained in the other... considering trigram/fuzzy or manual matching for these cases. Indeed, for 78 Kreise, a manual mapping is feasible. We only need to decide whether we want injectivity between NUTS-3 and Kreise, so every NUTS-3 code is associated with exactly one Kreis - Berlin has 12 Kreise, Aachen and Hannover have 2 Kreise each (the city and the ambient municipality).

# %% [markdown]
# There are various notations:
#
# - Saalkreis, 15265 -> Saale + Kreis
# - Dessau, kreisfreie Stadt
# - Landkreis Müritz
# - Rügen, Landkreis
# - Saarbrücken, Regionalverband and Saarbrücken, Landeshauptstadt
# - Dillingen a.d.Donau, Landkreis
# - Neustadt a.d.Aisch-Bad Windsheim, Landkreis
# - Wunsiedel i.Fichtelgebirge, Landkreis
# - Weiden i.d.OPf., kreisfreie Stadt
# - Neumarkt i.d.OPf., Landkreis
# - Greifswald, Hansestadt, kreisfreie Stadt
# - Neubrandenburg, Stadt,  kreisfreie Stadt
# - Niederschlesischer Oberlausitzkreis
#
# The variety in naming is significant. A first step would be to split off "Landkreis" and "kreisfreie Stadt" as the most frequently occuring qualifiers. But this would fail the distinction between "Aachen, kreisfreie Stadt" and "Aachen, Kreis" the moment we also split off the "Kreis" qualifier. In addition, "Landkreis" sometimes appears as the prefix and sometimes as the comma-separated postfix qualifier.
#
# The required matching rule for all cases, howeer, is nontrivial and require a more careful analysis. It's easy to provide a deterministic mapping table (dict) between these and NUTS-3 entities, if matching ones exist, and the matching decision is at the discretion of the analyst. But it's finite. Any new non-matching entries upstream would fail the determinsitic mapping. Therefore,
#
# 1. prepare to handle mismatches
# 2. prepare crop data imputation, e.g., from ambient k neighbors
# 3. weigh significance of out-of-focus regions
# 4. weigh significance of regions with n/a crop yield data
# 5. weigh significance of regions without recent data
# 6. if significant, consider joining a region center with the region of NUTS-3 does so, e.g., Aachen, Saarbruecken, Hannover; similarly, consider joining Berlin's Bezirke
# 7. write down the use cases supported by and the recognized limitations of the resulting data set
#
# We'll now attempt the simple approach of splitting off postfix qualifiers ", Landkreis" and ", kreisfreie Stadt" to see whether we get any duplicates and for how many we could uniquely and accurately restore a mapping to NUTS-3 - for which we'll also need to ensure the bijective uniqueness as a follow-up step.

# %%
# SEE https://regex101.com/
# SEE https://github.com/google/re2/wiki/Syntax (DuckDB uses re2)
# SEE https://duckdb.org/docs/stable/sql/functions/regular_expressions
# SEE https://duckdb.org/docs/stable/sql/functions/pattern_matching
# NOTE: advanced patterns such as negative predecessor (?!re) are not supported by re2.
split_result = con.sql("""
    select kreis_code, kreis_name
         -- Capture postfix notation:
         , regexp_extract(kreis_name, '^(.*?)(?:,\\s*(kreisfreie Stadt|Landkreis|Kreis|Landeshauptstadt))?$', 1) as kreis_name_base
         , regexp_extract(kreis_name, '^(.*?)(?:,\\s*(kreisfreie Stadt|Landkreis|Kreis|Landeshauptstadt))?$', 2) as kreis_qualifier
         , columns(* exclude(kreis_code, kreis_name))
    from result_df -- reusing that very resultset df from above, good we defined it

""")
split_result_df = split_result.df()
split_result_df
# Out:
#    kreis_code                     kreis_name   kreis_name_base  \
# 0       03156    Osterode am Harz, Landkreis  Osterode am Harz
# 1    03241001     Hannover, Landeshauptstadt          Hannover
# 2       03455           Friesland, Landkreis         Friesland
# 3       04011       Bremen, kreisfreie Stadt            Bremen
# 4       04012  Bremerhaven, kreisfreie Stadt       Bremerhaven
# ..        ...                            ...               ...
# 61      15357             Halberstadt, Kreis       Halberstadt
# 62      15362                      Ohrekreis         Ohrekreis
# 63      15364             Quedlinburg, Kreis       Quedlinburg
# 64      15367              Schönebeck, Kreis        Schönebeck
# 65      15369             Wernigerode, Kreis       Wernigerode
#
#      kreis_qualifier bundesland_code nuts1  is_bundesland  is_kreis  \
# 0          Landkreis              03   DE9          False      True
# 1   Landeshauptstadt              03   DE9          False     False
# 2          Landkreis              03   DE9          False      True
# 3   kreisfreie Stadt             NaN   NaN          False      True
# 4   kreisfreie Stadt             NaN   NaN          False      True
# ..               ...             ...   ...            ...       ...
# 61             Kreis              15   DEE          False      True
# 62                                15   DEE          False      True
# 63             Kreis              15   DEE          False      True
# 64             Kreis              15   DEE          False      True
# 65             Kreis              15   DEE          False      True
#
#     is_kreis_8  is_unexpected_kreis_code
# 0        False                     False
# 1         True                     False
# 2        False                     False
# 3        False                     False
# 4        False                     False
# ..         ...                       ...
# 61       False                     False
# 62       False                     False
# 63       False                     False
# 64       False                     False
# 65       False                     False
#
# [66 rows x 10 columns]

# %% [markdown]
# Brief summary: with "Kreis" qualifier included, we get 65 distinct `kreis_name_base` values out of 66, which means only Aachen is now duplicated. Saarbruecken with "Regionalverband" is the 2nd candidate. Only 11 rows remain without a base name.
#
# We'll now very quickly match them against NUTS-3, to see just how many of these remain unmatched.

# %%
nuts_to_kreise_split_result = con.sql("""
    select n3.nuts_id, n3.nuts_name, s.kreis_name_base, s.kreis_qualifier, s.kreis_name, s.kreis_code
    from split_result_df s
    left join nuts3 n3 on contains(lower(n3.nuts_name), lower(kreis_name_base)) or contains(lower(kreis_name_base), n3.nuts_name)
    where n3.cntr_code = 'DE'
    order by nuts_id
""")
nuts_to_kreise_split_result_df = nuts_to_kreise_split_result.df()
nuts_to_kreise_split_result_df
# Out:
#    NUTS_ID                         NUTS_NAME     kreis_name_base  \
# 0    DE501          Bremen, Kreisfreie Stadt              Bremen
# 1    DE502     Bremerhaven, Kreisfreie Stadt         Bremerhaven
# 2    DE80L                  Vorpommern-Rügen               Rügen
# 3    DE929                   Region Hannover            Hannover
# 4    DE94A                    Friesland (DE)           Friesland
# 5    DEA2D               Städteregion Aachen              Aachen
# 6    DEA2D               Städteregion Aachen              Aachen
# 7    DEC01       Regionalverband Saarbrücken         Saarbrücken
# 8    DED2F  Sächsische Schweiz-Osterzgebirge  Sächsische Schweiz
# 9    DEE01   Dessau-Roßlau, Kreisfreie Stadt              Dessau
# 10   DEE05                 Anhalt-Bitterfeld          Bitterfeld
# 11   DEF07                     Nordfriesland           Friesland
#
#      kreis_qualifier                     kreis_name kreis_code
# 0   kreisfreie Stadt       Bremen, kreisfreie Stadt      04011
# 1   kreisfreie Stadt  Bremerhaven, kreisfreie Stadt      04012
# 2          Landkreis               Rügen, Landkreis      13061
# 3   Landeshauptstadt     Hannover, Landeshauptstadt   03241001
# 4          Landkreis           Friesland, Landkreis      03455
# 5   kreisfreie Stadt       Aachen, kreisfreie Stadt   05334002
# 6              Kreis                  Aachen, Kreis      05354
# 7   Landeshauptstadt  Saarbrücken, Landeshauptstadt   10041100
# 8          Landkreis  Sächsische Schweiz, Landkreis      14287
# 9   kreisfreie Stadt       Dessau, kreisfreie Stadt      15101
# 10             Kreis              Bitterfeld, Kreis      15154
# 11         Landkreis           Friesland, Landkreis      03455

# %% [markdown]
# That's just 12 out of 55 expected.
#
# We see:
#
# - Exact matches up to title case (should have matched exactly after lowering the case):
#   * "Bremen, Kreisfreie Stadt" = "Bremen, kreisfreie Stadt"
#   * "Bremerhaven, Kreisfreie Stadt" = "Bremerhaven, kreisfreie Stadt"
# - "Region Hannover" ?= "Hannover, Landeshauptstadt" + ?
# - "Regionalverband Saarbrücken" <-> "Saarbrücken, Regionalverband"
# - Nordfriesland	≠ Friesland

# %%
con.sql("select nuts_id, nuts_name from nuts3 where contains(lower(nuts_name), 'saar')")
# Out:
# ┌─────────┬─────────────────────────────┐
# │ NUTS_ID │          NUTS_NAME          │
# │ varchar │           varchar           │
# ├─────────┼─────────────────────────────┤
# │ DEB25   │ Trier-Saarburg              │
# │ DEC01   │ Regionalverband Saarbrücken │
# │ DEC04   │ Saarlouis                   │
# │ DEC05   │ Saarpfalz-Kreis             │
# └─────────┴─────────────────────────────┘

# %%
con.sql("select nuts_id, nuts_name from nuts3 where contains(lower(nuts_name), 'freiberg')")
# Out:
# ┌─────────┬───────────┐
# │ NUTS_ID │ NUTS_NAME │
# │ varchar │  varchar  │
# └─────────┴───────────┘
#         0 rows

# %% [markdown]
# Recall that our focus region is Lausitz (Lusatia) + Brandenburg. Specifically some of its municipalities have gaps in the Kreis-level crop yield mapping to the NUTS-3 regions and hence polygons. We'll need to identify the individual municipalities and map them as constituents into the ambient NUTS-3 regions.
#
# In addition, some of the Kreise don't have yield data (null). So it's safe to discard them and focus on enhancing the mapping only for those with yield data.
#
# TODO: To make progress, we'll move on here; but we'll need to return to fortify the mapping.

# %% [markdown]
# ### Continue Clean-up

# %%
con.sql("""
        show tables
""")
# Out:
# ┌────────────────────────────────────────┐
# │                  name                  │
# │                varchar                 │
# ├────────────────────────────────────────┤
# │ data_source_registry                   │
# │ dwd_stations                           │
# │ dwd_stations_nuts3                     │
# │ kreise_crops                           │
# │ kreise_crops_raw                       │
# │ nuts0                                  │
# │ nuts1                                  │
# │ nuts1_names                            │
# │ nuts2                                  │
# │ nuts3                                  │
# │ nuts_hierarchy                         │
# │ reject_errors                          │
# │ reject_scans                           │
# │ verify_df                              │
# │ vw__mapping__kreise_to_nuts3           │
# │ vw__mapping__kreise_to_nuts3__failures │
# │ vw__mapping__nuts1_to_kreise           │
# │ vw_kreise_crops_not_in_df              │
# │ vw_kreise_crops_with_nuts1             │
# │ yields_bundesland                      │
# └────────────────────────────────────────┘
#                  20 rows

# %%
con.sql("""
    describe vw_kreise_crops_with_nuts1
""")
# Out:
# ┌──────────────────────────┬──────────────┬─────────┬─────────┬─────────┬─────────┐
# │       column_name        │ column_type  │  null   │   key   │ default │  extra  │
# │         varchar          │   varchar    │ varchar │ varchar │ varchar │ varchar │
# ├──────────────────────────┼──────────────┼─────────┼─────────┼─────────┼─────────┤
# │ year                     │ VARCHAR      │ YES     │ NULL    │ NULL    │ NULL    │
# │ kreis_code               │ VARCHAR      │ YES     │ NULL    │ NULL    │ NULL    │
# │ kreis_name               │ VARCHAR      │ YES     │ NULL    │ NULL    │ NULL    │
# │ crop_name                │ VARCHAR      │ YES     │ NULL    │ NULL    │ NULL    │
# │ yield_dt_ha_dec          │ DECIMAL(8,1) │ YES     │ NULL    │ NULL    │ NULL    │
# │ bundesland_code          │ VARCHAR      │ YES     │ NULL    │ NULL    │ NULL    │
# │ nuts1                    │ VARCHAR      │ YES     │ NULL    │ NULL    │ NULL    │
# │ is_country               │ BOOLEAN      │ YES     │ NULL    │ NULL    │ NULL    │
# │ is_bundesland            │ BOOLEAN      │ YES     │ NULL    │ NULL    │ NULL    │
# │ is_region                │ BOOLEAN      │ YES     │ NULL    │ NULL    │ NULL    │
# │ is_kreis                 │ BOOLEAN      │ YES     │ NULL    │ NULL    │ NULL    │
# │ is_kreis_8               │ BOOLEAN      │ YES     │ NULL    │ NULL    │ NULL    │
# │ is_unexpected_kreis_code │ BOOLEAN      │ YES     │ NULL    │ NULL    │ NULL    │
# └──────────────────────────┴──────────────┴─────────┴─────────┴─────────┴─────────┘
#   13 rows                                                               6 columns

# %%
con.sql("select * from vw_kreise_crops_with_nuts1 using sample 10 rows")
# Out:
# ┌─────────┬────────────┬─────────────────────────────────────────┬──────────────┬─────────────────┬─────────────────┬─────────┬────────────┬───────────────┬───────────┬──────────┬────────────┬──────────────────────────┐
# │  year   │ kreis_code │               kreis_name                │  crop_name   │ yield_dt_ha_dec │ bundesland_code │  nuts1  │ is_country │ is_bundesland │ is_region │ is_kreis │ is_kreis_8 │ is_unexpected_kreis_code │
# │ varchar │  varchar   │                 varchar                 │   varchar    │  decimal(8,1)   │     varchar     │ varchar │  boolean   │    boolean    │  boolean  │ boolean  │  boolean   │         boolean          │
# ├─────────┼────────────┼─────────────────────────────────────────┼──────────────┼─────────────────┼─────────────────┼─────────┼────────────┼───────────────┼───────────┼──────────┼────────────┼──────────────────────────┤
# │ 2022    │ 03103      │ Wolfsburg, kreisfreie Stadt             │ Silomais     │           419.8 │ 03              │ DE9     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 2003    │ 05754      │ Gütersloh, Kreis                        │ Winterraps   │            31.4 │ 05              │ DEA     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 2025    │ 05770      │ Minden-Lübbecke, Kreis                  │ Winterraps   │            46.2 │ 05              │ DEA     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 2016    │ 03358      │ Heidekreis                              │ Triticale    │            69.3 │ 03              │ DE9     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 2003    │ 05117      │ Mülheim an der Ruhr, kreisfreie Stadt   │ Winterweizen │            NULL │ 05              │ DEA     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 2017    │ 16055      │ Weimar, kreisfreie Stadt                │ Triticale    │            NULL │ 16              │ DEG     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 1999    │ 055        │ Münster, Regierungsbezirk               │ Silomais     │           467.3 │ 05              │ DEA     │ false      │ false         │ true      │ false    │ false      │ false                    │
# │ 2002    │ 03403      │ Oldenburg (Oldenburg), kreisfreie Stadt │ Winterweizen │            NULL │ 03              │ DE9     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 2007    │ 16070      │ Ilm-Kreis                               │ Winterweizen │            61.0 │ 16              │ DEG     │ false      │ false         │ false     │ true     │ false      │ false                    │
# │ 2004    │ 05315      │ Köln, kreisfreie Stadt                  │ Zuckerrüben  │           595.0 │ 05              │ DEA     │ false      │ false         │ false     │ true     │ false      │ false                    │
# └─────────┴────────────┴─────────────────────────────────────────┴──────────────┴─────────────────┴─────────────────┴─────────┴────────────┴───────────────┴───────────┴──────────┴────────────┴──────────────────────────┘
#   10 rows                                                                                                                                                                                                      13 columns

# %% [markdown]
# At the same time, as mentioned earlier, some of the Kreise don't have yield data.
#
# Let's check the data density (how much is null) - by grouping by cube (rolling up both ways), see https://duckdb.org/docs/stable/sql/query_syntax/grouping_sets.

# %%
cube_result = con.sql("""
    select crop_name, year, count(yield_dt_ha_dec) count_yields, count(*) count_obs, count(distinct kreis_name) count_kreise
    from vw_kreise_crops_with_nuts1
    group by cube (crop_name, year)
    order by crop_name, year
""")

cube_result_df = cube_result.df()
cube_result_df
# Out:
#     crop_name  year  count_yields  count_obs  count_kreise
# 0       Hafer  1999           440        527           519
# 1       Hafer  2000           432        527           519
# 2       Hafer  2001           436        526           518
# 3       Hafer  2002           428        527           519
# 4       Hafer  2003           428        527           519
# ..        ...   ...           ...        ...           ...
# 303       NaN  2022          2356       4560           456
# 304       NaN  2023          2304       4530           453
# 305       NaN  2024          2293       4560           456
# 306       NaN  2025          2251       4530           453
# 307       NaN   NaN         89830     129910           529
#
# [308 rows x 5 columns]

# %%
density_result_df = con.sql("""
    select cast(year as int) as year, crop_name, count(yield_dt_ha_dec) count_yields, count(*) count_obs, count(distinct kreis_name) count_kreise
    from vw_kreise_crops_with_nuts1
    where try_cast(year as int) is not null
    group by 1, 2
    order by 1, 2
""").df()

# %%
import plotly.express as px

fig = px.bar(
    density_result_df,
    x="year",
    y="count_yields",
    color="crop_name",
    barmode="stack",
    title="Yield observations by crop and year",
    labels={"year": "Year", "count_yields": "Non-null yields", "crop_name": "Crop"},
    hover_data={"count_obs": True, "count_kreise": True},
)
fig.update_layout(xaxis=dict(type="category"))
fig.show()

# %% [markdown]
# There were two substatial drop in the number of valid crop yield observations, and the quality has been declining.
#
# It's worth a separate analysis, which regions have been affected the most and why.

# %% [markdown]
# TODO: Enhance the final table schema
#
# 1. year should be an int
# 2. metric decitons (tenths of tons, dt/ha yield) should be converted into metric tons (t/ha yield): $1\,\text{t} = 10\,\text{dt}$.
# 3. to resolve the mapping gaps above, we need to make a domain-informed decision and potentially trade-off accuracy in outer-regions for agility in the focus regions (with accuracy there in mind): we're focusing on the Lusatia region and Winterweizen as our proxy.
# 4. make the ingestion decision on the cleaned-up data set
# 5. export to Parquet

# %% [markdown]
# ## 5. Ingest decision & data source registry
#
# Our nominal decision criterion was:
#
# > If we get ≥10 years of yield data for ≥80% of BB/SN Landkreise => **ingest**.
#
# Criterion|Assessment
# ---------|----------
# **Spatial granularity** | Kreise (NUTS-3) from Regionalstatistik + Bundesland (NUTS-1) from Genesis
# **Temporal coverage** | ~1999–2025, annual
# **Crop coverage** | 8-10 crop types incl. Winterweizen, Roggen, Winterraps, etc.
# **Germany coverage** | ~500 Kreise (NUTS-3) + 16 Bundesländer
# **BB/SN present** | OK: Both states at Kreise level, with "≥80% BB/SN Landkreise"
# **API reliability** | Official Destatis Genesis REST API, POST-only
# **Licence** | Datenlizenz Deutschland - Namensnennung - Version 2.0
#
# Therefore, the **decision** is to **INGEST**, such that: Kreise yields as primary; Bundesland yields as reference.

# %% [markdown]
# ## Release DuckDB
#
# Close DuckDB

# %%
db_size = DB_PATH.stat().st_size / 1024
print(f"DuckDB size: {db_size:.0f} KB")
con.close()
print("Done: DuckDB connection closed.")
# Out:
# DuckDB size: 4364 KB
# Done — DuckDB connection closed.
